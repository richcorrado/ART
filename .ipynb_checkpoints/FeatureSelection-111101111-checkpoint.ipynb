# %% [markdown]
# # Feature Selection on the 111101111 dataset

# %% [markdown]
# In this notebook we examine the result of dropping subsets of features that are linearly dependent or correlated to some degree.  We're specifically working on the dataset formed by dropping (31, 496, 524, 534, 917, 969, 1183, 1299), since that resulted in the 5th lowest validation error.

# %%
import itertools
import numpy as np
import pandas as pd

pd.set_option('display.precision',20)
pd.set_option('display.max_colwidth',100)

from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, cross_val_predict, KFold, cross_val_score, \
                                    GridSearchCV, RandomizedSearchCV, ShuffleSplit 
from time import time
from scipy.stats import randint as sp_randint

import matplotlib.pylab as plt
from matplotlib.pylab import rcParams
from matplotlib import pyplot
rcParams['figure.figsize'] = 12, 4
# %matplotlib inline

# %%
# def to compare goodness of fit on training set
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
# Cross-validation sets
kfold = KFold(n_splits=10, random_state=7)

# We are using LassoLarsCV as part of our metric
lr = linear_model.LassoLarsCV(verbose=False, max_iter=5000,precompute='auto', cv=kfold, max_n_alphas=1000, n_jobs=-1)

# %%
df = pd.read_csv("./input/train_tidy_111101111.csv")

# %%
ss = ShuffleSplit(n_splits=1, test_size=0.20, random_state=573)

# %%
X = df.values

# %%
for train_idx, validation_idx in ss.split(X):
    train_df = df.iloc[train_idx]
    validation_df = df.iloc[validation_idx]

# %% [markdown]
# We will establish a baseline by keeping all features.

# %%
y_validation = validation_df['SalePrice'].values
x_validation = validation_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'],axis=1).values
y_train = train_df['SalePrice'].values
x_train = train_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'],axis=1).values
lr.fit(x_train, y_train)
y_pred = lr.predict(x_validation)
baseline = rmse(y_validation, y_pred)
baseline
# Out:
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 304 iterations, i.e. alpha=4.659e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 313 iterations, i.e. alpha=4.105e-06, with an active set of 245 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 313 iterations, i.e. alpha=4.078e-06, with an active set of 245 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 314 iterations, alpha=4.105e-06, previous alpha=4.014e-06, with an active set of 245 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.975e-05, previous alpha=2.666e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=9.051e-05, previous alpha=2.787e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.550e-04, previous alpha=2.954e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=4.863e-04, previous alpha=3.178e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 272 iterations, i.e. alpha=8.900e-06, with an active set of 222 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 279 iterations, i.e. alpha=7.846e-06, with an active set of 225 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 300 iterations, i.e. alpha=5.324e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 300 iterations, i.e. alpha=5.211e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 304 iterations, alpha=5.264e-06, previous alpha=5.057e-06, with an active set of 245 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=1.201e-04, previous alpha=2.513e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 356 iterations, alpha=2.799e-04, previous alpha=1.807e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=6.365e-05, previous alpha=2.068e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 351 iterations, alpha=6.302e-04, previous alpha=3.296e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# 0.10398725860824831

# %% [markdown]
# ## Features

# %% [markdown]
# We have a collection of Features, some of which were identified to be of potentially low-quality in predicting the response, others of which are known to be highly correlated with other Features.  We want to identify subsets of features that we can drop to improve the regression.

# %%
drop_cands = [
    'LotFrontage', 'LotArea', 'BsmtUnfSF', 'LowQualFinSF',
    'LogGrLivArea', 
    'GrLivArea', 'TotalHouseArea', 'LivArea', 'LivAreaWt', 'AllSizesSum', 'AllSizesSumLin', 'AreasSum',
    'X1stFlrSF','X1stLin', 'X2ndFlrSF', 'X2ndLin',
    'TotalBath', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
    'Age', 'AgeLin', 'RemodAgeLin','RemodAge',
    'MasVnrArea', 'MasVnrAreaLin',
    'DeckPorchLin','WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', 'X3SsnPorch', 'ScreenPorch'
]

# %%
corr_df = df[drop_cands].corr()

# %%
corr_df[corr_df > 0.75]
# Out:
#                 LotFrontage                 LotArea  BsmtUnfSF  LowQualFinSF  \
# LotFrontage             1.0                     NaN        NaN           NaN
# LotArea                 NaN  1.00000000000000000000        NaN           NaN
# BsmtUnfSF               NaN                     NaN        1.0           NaN
# LowQualFinSF            NaN                     NaN        NaN           1.0
# LogGrLivArea            NaN                     NaN        NaN           NaN
# GrLivArea               NaN                     NaN        NaN           NaN
# TotalHouseArea          NaN                     NaN        NaN           NaN
# LivArea                 NaN                     NaN        NaN           NaN
# LivAreaWt               NaN                     NaN        NaN           NaN
# AllSizesSum             NaN  0.98607940814595906875        NaN           NaN
# AllSizesSumLin          NaN                     NaN        NaN           NaN
# AreasSum                NaN                     NaN        NaN           NaN
# X1stFlrSF               NaN                     NaN        NaN           NaN
# X1stLin                 NaN                     NaN        NaN           NaN
# X2ndFlrSF               NaN                     NaN        NaN           NaN
# X2ndLin                 NaN                     NaN        NaN           NaN
# TotalBath               NaN                     NaN        NaN           NaN
# BsmtFullBath            NaN                     NaN        NaN           NaN
# BsmtHalfBath            NaN                     NaN        NaN           NaN
# FullBath                NaN                     NaN        NaN           NaN
# HalfBath                NaN                     NaN        NaN           NaN
# Age                     NaN                     NaN        NaN           NaN
# AgeLin                  NaN                     NaN        NaN           NaN
# RemodAgeLin             NaN                     NaN        NaN           NaN
# RemodAge                NaN                     NaN        NaN           NaN
# MasVnrArea              NaN                     NaN        NaN           NaN
# MasVnrAreaLin           NaN                     NaN        NaN           NaN
# DeckPorchLin            NaN                     NaN        NaN           NaN
# WoodDeckSF              NaN                     NaN        NaN           NaN
# OpenPorchSF             NaN                     NaN        NaN           NaN
# EnclosedPorch           NaN                     NaN        NaN           NaN
# X3SsnPorch              NaN                     NaN        NaN           NaN
# ScreenPorch             NaN                     NaN        NaN           NaN
#
#                           LogGrLivArea               GrLivArea  \
# LotFrontage                        NaN                     NaN
# LotArea                            NaN                     NaN
# BsmtUnfSF                          NaN                     NaN
# LowQualFinSF                       NaN                     NaN
# LogGrLivArea    1.00000000000000000000  0.97571040483788185060
# GrLivArea       0.97571040483788185060  1.00000000000000000000
# TotalHouseArea  0.86044027269164313765  0.83545864922664636598
# LivArea         0.76328680989731989559  0.76744920567291741165
# LivAreaWt       0.91902084173143094858  0.91454747158955840280
# AllSizesSum                        NaN                     NaN
# AllSizesSumLin                     NaN                     NaN
# AreasSum        0.83239768317627527150  0.82055141940421116864
# X1stFlrSF                          NaN                     NaN
# X1stLin                            NaN                     NaN
# X2ndFlrSF                          NaN                     NaN
# X2ndLin                            NaN                     NaN
# TotalBath                          NaN                     NaN
# BsmtFullBath                       NaN                     NaN
# BsmtHalfBath                       NaN                     NaN
# FullBath                           NaN                     NaN
# HalfBath                           NaN                     NaN
# Age                                NaN                     NaN
# AgeLin                             NaN                     NaN
# RemodAgeLin                        NaN                     NaN
# RemodAge                           NaN                     NaN
# MasVnrArea                         NaN                     NaN
# MasVnrAreaLin                      NaN                     NaN
# DeckPorchLin                       NaN                     NaN
# WoodDeckSF                         NaN                     NaN
# OpenPorchSF                        NaN                     NaN
# EnclosedPorch                      NaN                     NaN
# X3SsnPorch                         NaN                     NaN
# ScreenPorch                        NaN                     NaN
#
#                         TotalHouseArea                 LivArea  \
# LotFrontage                        NaN                     NaN
# LotArea                            NaN                     NaN
# BsmtUnfSF                          NaN                     NaN
# LowQualFinSF                       NaN                     NaN
# LogGrLivArea    0.86044027269164313765  0.76328680989731989559
# GrLivArea       0.83545864922664636598  0.76744920567291741165
# TotalHouseArea  1.00000000000000000000  0.80194163659726169779
# LivArea         0.80194163659726169779  1.00000000000000000000
# LivAreaWt       0.87563920203640288609  0.94525675874917547414
# AllSizesSum                        NaN                     NaN
# AllSizesSumLin                     NaN                     NaN
# AreasSum        0.93292442520879703682  0.79505023820336828688
# X1stFlrSF                          NaN                     NaN
# X1stLin                            NaN                     NaN
# X2ndFlrSF                          NaN                     NaN
# X2ndLin                            NaN                     NaN
# TotalBath                          NaN                     NaN
# BsmtFullBath                       NaN                     NaN
# BsmtHalfBath                       NaN                     NaN
# FullBath                           NaN                     NaN
# HalfBath                           NaN                     NaN
# Age                                NaN                     NaN
# AgeLin                             NaN                     NaN
# RemodAgeLin                        NaN                     NaN
# RemodAge                           NaN                     NaN
# MasVnrArea                         NaN                     NaN
# MasVnrAreaLin                      NaN                     NaN
# DeckPorchLin                       NaN                     NaN
# WoodDeckSF                         NaN                     NaN
# OpenPorchSF                        NaN                     NaN
# EnclosedPorch                      NaN                     NaN
# X3SsnPorch                         NaN                     NaN
# ScreenPorch                        NaN                     NaN
#
#                              LivAreaWt             AllSizesSum     ...       \
# LotFrontage                        NaN                     NaN     ...
# LotArea                            NaN  0.98607940814595906875     ...
# BsmtUnfSF                          NaN                     NaN     ...
# LowQualFinSF                       NaN                     NaN     ...
# LogGrLivArea    0.91902084173143094858                     NaN     ...
# GrLivArea       0.91454747158955840280                     NaN     ...
# TotalHouseArea  0.87563920203640288609                     NaN     ...
# LivArea         0.94525675874917547414                     NaN     ...
# LivAreaWt       1.00000000000000000000                     NaN     ...
# AllSizesSum                        NaN  1.00000000000000000000     ...
# AllSizesSumLin                     NaN                     NaN     ...
# AreasSum        0.86170282055561275847                     NaN     ...
# X1stFlrSF                          NaN                     NaN     ...
# X1stLin                            NaN                     NaN     ...
# X2ndFlrSF                          NaN                     NaN     ...
# X2ndLin                            NaN                     NaN     ...
# TotalBath                          NaN                     NaN     ...
# BsmtFullBath                       NaN                     NaN     ...
# BsmtHalfBath                       NaN                     NaN     ...
# FullBath                           NaN                     NaN     ...
# HalfBath                           NaN                     NaN     ...
# Age                                NaN                     NaN     ...
# AgeLin                             NaN                     NaN     ...
# RemodAgeLin                        NaN                     NaN     ...
# RemodAge                           NaN                     NaN     ...
# MasVnrArea                         NaN                     NaN     ...
# MasVnrAreaLin                      NaN                     NaN     ...
# DeckPorchLin                       NaN                     NaN     ...
# WoodDeckSF                         NaN                     NaN     ...
# OpenPorchSF                        NaN                     NaN     ...
# EnclosedPorch                      NaN                     NaN     ...
# X3SsnPorch                         NaN                     NaN     ...
# ScreenPorch                        NaN                     NaN     ...
#
#                 RemodAgeLin  RemodAge              MasVnrArea  \
# LotFrontage             NaN       NaN                     NaN
# LotArea                 NaN       NaN                     NaN
# BsmtUnfSF               NaN       NaN                     NaN
# LowQualFinSF            NaN       NaN                     NaN
# LogGrLivArea            NaN       NaN                     NaN
# GrLivArea               NaN       NaN                     NaN
# TotalHouseArea          NaN       NaN                     NaN
# LivArea                 NaN       NaN                     NaN
# LivAreaWt               NaN       NaN                     NaN
# AllSizesSum             NaN       NaN                     NaN
# AllSizesSumLin          NaN       NaN                     NaN
# AreasSum                NaN       NaN                     NaN
# X1stFlrSF               NaN       NaN                     NaN
# X1stLin                 NaN       NaN                     NaN
# X2ndFlrSF               NaN       NaN                     NaN
# X2ndLin                 NaN       NaN                     NaN
# TotalBath               NaN       NaN                     NaN
# BsmtFullBath            NaN       NaN                     NaN
# BsmtHalfBath            NaN       NaN                     NaN
# FullBath                NaN       NaN                     NaN
# HalfBath                NaN       NaN                     NaN
# Age                     NaN       NaN                     NaN
# AgeLin                  NaN       NaN                     NaN
# RemodAgeLin             1.0       NaN                     NaN
# RemodAge                NaN       1.0                     NaN
# MasVnrArea              NaN       NaN  1.00000000000000000000
# MasVnrAreaLin           NaN       NaN  0.91180384640372880156
# DeckPorchLin            NaN       NaN                     NaN
# WoodDeckSF              NaN       NaN                     NaN
# OpenPorchSF             NaN       NaN                     NaN
# EnclosedPorch           NaN       NaN                     NaN
# X3SsnPorch              NaN       NaN                     NaN
# ScreenPorch             NaN       NaN                     NaN
#
#                          MasVnrAreaLin  DeckPorchLin  WoodDeckSF  OpenPorchSF  \
# LotFrontage                        NaN           NaN         NaN          NaN
# LotArea                            NaN           NaN         NaN          NaN
# BsmtUnfSF                          NaN           NaN         NaN          NaN
# LowQualFinSF                       NaN           NaN         NaN          NaN
# LogGrLivArea                       NaN           NaN         NaN          NaN
# GrLivArea                          NaN           NaN         NaN          NaN
# TotalHouseArea                     NaN           NaN         NaN          NaN
# LivArea                            NaN           NaN         NaN          NaN
# LivAreaWt                          NaN           NaN         NaN          NaN
# AllSizesSum                        NaN           NaN         NaN          NaN
# AllSizesSumLin                     NaN           NaN         NaN          NaN
# AreasSum                           NaN           NaN         NaN          NaN
# X1stFlrSF                          NaN           NaN         NaN          NaN
# X1stLin                            NaN           NaN         NaN          NaN
# X2ndFlrSF                          NaN           NaN         NaN          NaN
# X2ndLin                            NaN           NaN         NaN          NaN
# TotalBath                          NaN           NaN         NaN          NaN
# BsmtFullBath                       NaN           NaN         NaN          NaN
# BsmtHalfBath                       NaN           NaN         NaN          NaN
# FullBath                           NaN           NaN         NaN          NaN
# HalfBath                           NaN           NaN         NaN          NaN
# Age                                NaN           NaN         NaN          NaN
# AgeLin                             NaN           NaN         NaN          NaN
# RemodAgeLin                        NaN           NaN         NaN          NaN
# RemodAge                           NaN           NaN         NaN          NaN
# MasVnrArea      0.91180384640372880156           NaN         NaN          NaN
# MasVnrAreaLin   1.00000000000000000000           NaN         NaN          NaN
# DeckPorchLin                       NaN           1.0         NaN          NaN
# WoodDeckSF                         NaN           NaN         1.0          NaN
# OpenPorchSF                        NaN           NaN         NaN          1.0
# EnclosedPorch                      NaN           NaN         NaN          NaN
# X3SsnPorch                         NaN           NaN         NaN          NaN
# ScreenPorch                        NaN           NaN         NaN          NaN
#
#                 EnclosedPorch  X3SsnPorch  ScreenPorch
# LotFrontage               NaN         NaN          NaN
# LotArea                   NaN         NaN          NaN
# BsmtUnfSF                 NaN         NaN          NaN
# LowQualFinSF              NaN         NaN          NaN
# LogGrLivArea              NaN         NaN          NaN
# GrLivArea                 NaN         NaN          NaN
# TotalHouseArea            NaN         NaN          NaN
# LivArea                   NaN         NaN          NaN
# LivAreaWt                 NaN         NaN          NaN
# AllSizesSum               NaN         NaN          NaN
# AllSizesSumLin            NaN         NaN          NaN
# AreasSum                  NaN         NaN          NaN
# X1stFlrSF                 NaN         NaN          NaN
# X1stLin                   NaN         NaN          NaN
# X2ndFlrSF                 NaN         NaN          NaN
# X2ndLin                   NaN         NaN          NaN
# TotalBath                 NaN         NaN          NaN
# BsmtFullBath              NaN         NaN          NaN
# BsmtHalfBath              NaN         NaN          NaN
# FullBath                  NaN         NaN          NaN
# HalfBath                  NaN         NaN          NaN
# Age                       NaN         NaN          NaN
# AgeLin                    NaN         NaN          NaN
# RemodAgeLin               NaN         NaN          NaN
# RemodAge                  NaN         NaN          NaN
# MasVnrArea                NaN         NaN          NaN
# MasVnrAreaLin             NaN         NaN          NaN
# DeckPorchLin              NaN         NaN          NaN
# WoodDeckSF                NaN         NaN          NaN
# OpenPorchSF               NaN         NaN          NaN
# EnclosedPorch             1.0         NaN          NaN
# X3SsnPorch                NaN         1.0          NaN
# ScreenPorch               NaN         NaN          1.0
#
# [33 rows x 33 columns]

# %% [markdown]
# We'll restrict our drop set to the highly correlated features to make this more readable,

# %%
drop_cands = [
    'LotArea', 'LogGrLivArea', 
    'GrLivArea', 'TotalHouseArea', 'LivArea', 'LivAreaWt', 'AllSizesSum', 'AreasSum',
    'X1stFlrSF','X1stLin', 'TotalBath', 'FullBath', 'MasVnrArea', 'MasVnrAreaLin'
]

# %%
corr_df = df[drop_cands].corr()

# %%
corr_df[corr_df > 0.75]
# Out:
#                                LotArea            LogGrLivArea  \
# LotArea         1.00000000000000000000                     NaN
# LogGrLivArea                       NaN  1.00000000000000000000
# GrLivArea                          NaN  0.97571040483788185060
# TotalHouseArea                     NaN  0.86044027269164313765
# LivArea                            NaN  0.76328680989731989559
# LivAreaWt                          NaN  0.91902084173143094858
# AllSizesSum     0.98607940814595906875                     NaN
# AreasSum                           NaN  0.83239768317627527150
# X1stFlrSF                          NaN                     NaN
# X1stLin                            NaN                     NaN
# TotalBath                          NaN                     NaN
# FullBath                           NaN                     NaN
# MasVnrArea                         NaN                     NaN
# MasVnrAreaLin                      NaN                     NaN
#
#                              GrLivArea          TotalHouseArea  \
# LotArea                            NaN                     NaN
# LogGrLivArea    0.97571040483788185060  0.86044027269164313765
# GrLivArea       1.00000000000000000000  0.83545864922664636598
# TotalHouseArea  0.83545864922664636598  1.00000000000000000000
# LivArea         0.76744920567291741165  0.80194163659726169779
# LivAreaWt       0.91454747158955840280  0.87563920203640288609
# AllSizesSum                        NaN                     NaN
# AreasSum        0.82055141940421116864  0.93292442520879703682
# X1stFlrSF                          NaN                     NaN
# X1stLin                            NaN                     NaN
# TotalBath                          NaN                     NaN
# FullBath                           NaN                     NaN
# MasVnrArea                         NaN                     NaN
# MasVnrAreaLin                      NaN                     NaN
#
#                                LivArea               LivAreaWt  \
# LotArea                            NaN                     NaN
# LogGrLivArea    0.76328680989731989559  0.91902084173143094858
# GrLivArea       0.76744920567291741165  0.91454747158955840280
# TotalHouseArea  0.80194163659726169779  0.87563920203640288609
# LivArea         1.00000000000000000000  0.94525675874917547414
# LivAreaWt       0.94525675874917547414  1.00000000000000000000
# AllSizesSum                        NaN                     NaN
# AreasSum        0.79505023820336828688  0.86170282055561275847
# X1stFlrSF                          NaN                     NaN
# X1stLin                            NaN                     NaN
# TotalBath                          NaN                     NaN
# FullBath                           NaN                     NaN
# MasVnrArea                         NaN                     NaN
# MasVnrAreaLin                      NaN                     NaN
#
#                            AllSizesSum                AreasSum  \
# LotArea         0.98607940814595906875                     NaN
# LogGrLivArea                       NaN  0.83239768317627527150
# GrLivArea                          NaN  0.82055141940421116864
# TotalHouseArea                     NaN  0.93292442520879703682
# LivArea                            NaN  0.79505023820336828688
# LivAreaWt                          NaN  0.86170282055561275847
# AllSizesSum     1.00000000000000000000                     NaN
# AreasSum                           NaN  1.00000000000000000000
# X1stFlrSF                          NaN                     NaN
# X1stLin                            NaN                     NaN
# TotalBath                          NaN                     NaN
# FullBath                           NaN                     NaN
# MasVnrArea                         NaN                     NaN
# MasVnrAreaLin                      NaN                     NaN
#
#                             X1stFlrSF                X1stLin  \
# LotArea                           NaN                    NaN
# LogGrLivArea                      NaN                    NaN
# GrLivArea                         NaN                    NaN
# TotalHouseArea                    NaN                    NaN
# LivArea                           NaN                    NaN
# LivAreaWt                         NaN                    NaN
# AllSizesSum                       NaN                    NaN
# AreasSum                          NaN                    NaN
# X1stFlrSF       1.0000000000000000000  0.9790535893861382899
# X1stLin         0.9790535893861382899  1.0000000000000000000
# TotalBath                         NaN                    NaN
# FullBath                          NaN                    NaN
# MasVnrArea                        NaN                    NaN
# MasVnrAreaLin                     NaN                    NaN
#
#                              TotalBath                FullBath  \
# LotArea                            NaN                     NaN
# LogGrLivArea                       NaN                     NaN
# GrLivArea                          NaN                     NaN
# TotalHouseArea                     NaN                     NaN
# LivArea                            NaN                     NaN
# LivAreaWt                          NaN                     NaN
# AllSizesSum                        NaN                     NaN
# AreasSum                           NaN                     NaN
# X1stFlrSF                          NaN                     NaN
# X1stLin                            NaN                     NaN
# TotalBath       1.00000000000000000000  0.84327816004332079025
# FullBath        0.84327816004332079025  1.00000000000000000000
# MasVnrArea                         NaN                     NaN
# MasVnrAreaLin                      NaN                     NaN
#
#                             MasVnrArea           MasVnrAreaLin
# LotArea                            NaN                     NaN
# LogGrLivArea                       NaN                     NaN
# GrLivArea                          NaN                     NaN
# TotalHouseArea                     NaN                     NaN
# LivArea                            NaN                     NaN
# LivAreaWt                          NaN                     NaN
# AllSizesSum                        NaN                     NaN
# AreasSum                           NaN                     NaN
# X1stFlrSF                          NaN                     NaN
# X1stLin                            NaN                     NaN
# TotalBath                          NaN                     NaN
# FullBath                           NaN                     NaN
# MasVnrArea      1.00000000000000000000  0.91180384640372880156
# MasVnrAreaLin   0.91180384640372880156  1.00000000000000000000

# %% [markdown]
# Let's first compare the pairs.

# %%
drop_cands = ['LotArea', 'AllSizesSum']

# %%
col_drop_results_df = pd.DataFrame(dtype = 'float64')
count = 0
for L in range(0, len(drop_cands)+1):
        for subset in itertools.combinations(drop_cands, L):
                drop_cols = list(subset)
                col_drop_results_df.loc[count, 'Dropped'] = str(subset)
                x_train = train_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                x_validation = validation_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                lr.fit(x_train, y_train)
                y_pred = lr.predict(x_validation)
                error = rmse(y_validation, y_pred)
                col_drop_results_df.loc[count, 'RMSE'] = error
                col_drop_results_df.loc[count, 'Diff from Base'] = error - baseline                
                count += 1
output_df = col_drop_results_df.sort_values(['RMSE'])
# Out:
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.975e-05, previous alpha=2.666e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 304 iterations, i.e. alpha=4.659e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 313 iterations, i.e. alpha=4.105e-06, with an active set of 245 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 313 iterations, i.e. alpha=4.078e-06, with an active set of 245 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 314 iterations, alpha=4.105e-06, previous alpha=4.014e-06, with an active set of 245 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=9.051e-05, previous alpha=2.787e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.550e-04, previous alpha=2.954e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=4.863e-04, previous alpha=3.178e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 272 iterations, i.e. alpha=8.900e-06, with an active set of 222 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 279 iterations, i.e. alpha=7.846e-06, with an active set of 225 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 300 iterations, i.e. alpha=5.324e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 300 iterations, i.e. alpha=5.211e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 304 iterations, alpha=5.264e-06, previous alpha=5.057e-06, with an active set of 245 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=1.201e-04, previous alpha=2.513e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 356 iterations, alpha=2.799e-04, previous alpha=1.807e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 351 iterations, alpha=6.302e-04, previous alpha=3.296e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=6.365e-05, previous alpha=2.068e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.874e-04, previous alpha=2.954e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=4.730e-05, previous alpha=2.666e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.112e-04, previous alpha=2.787e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 335 iterations, i.e. alpha=2.161e-06, with an active set of 257 regressors, and the smallest cholesky pivot element being 2.980e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=2.427e-05, previous alpha=3.195e-06, with an active set of 249 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.123e-04, previous alpha=1.603e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=2.198e-04, previous alpha=2.513e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 272 iterations, i.e. alpha=8.785e-06, with an active set of 222 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 317 iterations, alpha=3.540e-06, previous alpha=3.537e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 356 iterations, alpha=2.825e-04, previous alpha=1.807e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 351 iterations, alpha=7.285e-04, previous alpha=3.296e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=2.551e-04, previous alpha=2.161e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.874e-04, previous alpha=2.955e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 311 iterations, i.e. alpha=4.611e-06, with an active set of 243 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 311 iterations, i.e. alpha=4.581e-06, with an active set of 243 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 311 iterations, i.e. alpha=4.531e-06, with an active set of 243 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 312 iterations, alpha=4.611e-06, previous alpha=4.509e-06, with an active set of 243 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=9.051e-05, previous alpha=2.749e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.974e-05, previous alpha=2.667e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=6.087e-04, previous alpha=2.397e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=1.956e-03, previous alpha=2.769e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 272 iterations, i.e. alpha=8.932e-06, with an active set of 222 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 279 iterations, i.e. alpha=7.889e-06, with an active set of 225 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 288 iterations, alpha=6.731e-06, previous alpha=6.730e-06, with an active set of 233 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 356 iterations, alpha=2.825e-04, previous alpha=1.808e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=4.436e-04, previous alpha=2.161e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 352 iterations, alpha=7.359e-04, previous alpha=3.304e-06, with an active set of 261 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.281e-04, previous alpha=2.985e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.974e-04, previous alpha=2.782e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 299 iterations, i.e. alpha=6.445e-06, with an active set of 239 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 299 iterations, i.e. alpha=6.404e-06, with an active set of 239 regressors, and the smallest cholesky pivot element being 3.650e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 303 iterations, alpha=6.209e-06, previous alpha=6.162e-06, with an active set of 240 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=2.049e-04, previous alpha=2.915e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=3.949e-05, previous alpha=2.812e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 275 iterations, i.e. alpha=9.506e-06, with an active set of 219 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=3.181e-04, previous alpha=2.397e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 334 iterations, alpha=3.243e-06, previous alpha=3.243e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=4.933e-04, previous alpha=2.589e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=4.527e-05, previous alpha=3.776e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.706e-04, previous alpha=2.123e-06, with an active set of 257 regressors.
#   ConvergenceWarning)

# %%
output_df
# Out:
#                       Dropped                    RMSE          Diff from Base
# 0                          ()  0.10398725860824831191  0.00000000000000000000
# 2            ('AllSizesSum',)  0.10407895525196883546  0.00009169664372052355
# 3  ('LotArea', 'AllSizesSum')  0.10412311116080383289  0.00013585255255552098
# 1                ('LotArea',)  0.10441193560675399166  0.00042467699850567975

# %% [markdown]
# We should keep these features.

# %%
drop_cands = ['X1stFlrSF','X1stLin']

# %%
col_drop_results_df = pd.DataFrame(dtype = 'float64')
count = 0
for L in range(0, len(drop_cands)+1):
        for subset in itertools.combinations(drop_cands, L):
                drop_cols = list(subset)
                col_drop_results_df.loc[count, 'Dropped'] = str(subset)
                x_train = train_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                x_validation = validation_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                lr.fit(x_train, y_train)
                y_pred = lr.predict(x_validation)
                error = rmse(y_validation, y_pred)
                col_drop_results_df.loc[count, 'RMSE'] = error
                col_drop_results_df.loc[count, 'Diff from Base'] = error - baseline                
                count += 1
output_df = col_drop_results_df.sort_values(['RMSE'])
# Out:
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.975e-05, previous alpha=2.666e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.550e-04, previous alpha=2.954e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=9.051e-05, previous alpha=2.787e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 304 iterations, i.e. alpha=4.659e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 313 iterations, i.e. alpha=4.105e-06, with an active set of 245 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 313 iterations, i.e. alpha=4.078e-06, with an active set of 245 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 314 iterations, alpha=4.105e-06, previous alpha=4.014e-06, with an active set of 245 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=4.863e-04, previous alpha=3.178e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 272 iterations, i.e. alpha=8.900e-06, with an active set of 222 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 279 iterations, i.e. alpha=7.846e-06, with an active set of 225 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 300 iterations, i.e. alpha=5.324e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=1.201e-04, previous alpha=2.513e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 300 iterations, i.e. alpha=5.211e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 304 iterations, alpha=5.264e-06, previous alpha=5.057e-06, with an active set of 245 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 356 iterations, alpha=2.799e-04, previous alpha=1.807e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 351 iterations, alpha=6.302e-04, previous alpha=3.296e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=6.365e-05, previous alpha=2.068e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.164e-05, previous alpha=2.776e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=3.078e-04, previous alpha=2.886e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 335 iterations, i.e. alpha=2.065e-06, with an active set of 257 regressors, and the smallest cholesky pivot element being 3.942e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 335 iterations, i.e. alpha=2.031e-06, with an active set of 257 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 336 iterations, alpha=2.065e-06, previous alpha=2.020e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.874e-04, previous alpha=2.954e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=4.228e-05, previous alpha=3.151e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 272 iterations, i.e. alpha=8.785e-06, with an active set of 222 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 321 iterations, alpha=3.425e-06, previous alpha=3.374e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=2.408e-04, previous alpha=2.649e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 350 iterations, alpha=1.142e-03, previous alpha=1.885e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 351 iterations, alpha=7.285e-04, previous alpha=3.296e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=2.551e-04, previous alpha=2.161e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=7.120e-05, previous alpha=2.514e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.082e-04, previous alpha=3.129e-06, with an active set of 249 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 313 iterations, i.e. alpha=4.404e-06, with an active set of 241 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=7.324e-05, previous alpha=2.032e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.677e-04, previous alpha=2.692e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=9.635e-04, previous alpha=3.190e-06, with an active set of 247 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.502e-03, previous alpha=2.532e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 270 iterations, i.e. alpha=9.216e-06, with an active set of 220 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 315 iterations, i.e. alpha=4.330e-06, with an active set of 249 regressors, and the smallest cholesky pivot element being 2.980e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=1.030e-03, previous alpha=2.178e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.874e-04, previous alpha=3.779e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=9.458e-05, previous alpha=2.787e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.985e-03, previous alpha=2.528e-06, with an active set of 249 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=3.751e-05, previous alpha=2.651e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 324 iterations, i.e. alpha=3.224e-06, with an active set of 250 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.969e-05, previous alpha=3.009e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=3.653e-05, previous alpha=1.864e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.487e-04, previous alpha=3.291e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 260 iterations, i.e. alpha=1.044e-05, with an active set of 218 regressors, and the smallest cholesky pivot element being 2.788e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.164e-05, previous alpha=3.126e-06, with an active set of 249 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 320 iterations, i.e. alpha=3.055e-06, with an active set of 250 regressors, and the smallest cholesky pivot element being 2.356e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 320 iterations, i.e. alpha=3.036e-06, with an active set of 250 regressors, and the smallest cholesky pivot element being 2.356e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 321 iterations, i.e. alpha=2.846e-06, with an active set of 251 regressors, and the smallest cholesky pivot element being 6.747e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 323 iterations, alpha=2.872e-06, previous alpha=2.753e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=8.030e-04, previous alpha=3.527e-06, with an active set of 250 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.174e-04, previous alpha=2.799e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=4.595e-04, previous alpha=2.244e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=6.275e-04, previous alpha=3.490e-06, with an active set of 252 regressors.
#   ConvergenceWarning)

# %%
output_df
# Out:
#                     Dropped                    RMSE          Diff from Base
# 0                        ()  0.10398725860824831191  0.00000000000000000000
# 3  ('X1stFlrSF', 'X1stLin')  0.10402357574387925687  0.00003631713563094496
# 2              ('X1stLin',)  0.10411523427667691843  0.00012797566842860653
# 1            ('X1stFlrSF',)  0.10500284428334610842  0.00101558567509779651

# %%
drop_cands = ['TotalBath', 'FullBath']

# %%
col_drop_results_df = pd.DataFrame(dtype = 'float64')
count = 0
for L in range(0, len(drop_cands)+1):
        for subset in itertools.combinations(drop_cands, L):
                drop_cols = list(subset)
                col_drop_results_df.loc[count, 'Dropped'] = str(subset)
                x_train = train_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                x_validation = validation_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                lr.fit(x_train, y_train)
                y_pred = lr.predict(x_validation)
                error = rmse(y_validation, y_pred)
                col_drop_results_df.loc[count, 'RMSE'] = error
                col_drop_results_df.loc[count, 'Diff from Base'] = error - baseline                
                count += 1
output_df = col_drop_results_df.sort_values(['RMSE'])
# Out:
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.975e-05, previous alpha=2.666e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 304 iterations, i.e. alpha=4.659e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 313 iterations, i.e. alpha=4.105e-06, with an active set of 245 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 313 iterations, i.e. alpha=4.078e-06, with an active set of 245 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 314 iterations, alpha=4.105e-06, previous alpha=4.014e-06, with an active set of 245 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.550e-04, previous alpha=2.954e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=9.051e-05, previous alpha=2.787e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=4.863e-04, previous alpha=3.178e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 272 iterations, i.e. alpha=8.900e-06, with an active set of 222 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 279 iterations, i.e. alpha=7.846e-06, with an active set of 225 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 300 iterations, i.e. alpha=5.324e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 300 iterations, i.e. alpha=5.211e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 304 iterations, alpha=5.264e-06, previous alpha=5.057e-06, with an active set of 245 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=1.201e-04, previous alpha=2.513e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 351 iterations, alpha=6.302e-04, previous alpha=3.296e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 356 iterations, alpha=2.799e-04, previous alpha=1.807e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=6.365e-05, previous alpha=2.068e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 308 iterations, i.e. alpha=4.764e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 3.942e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=7.146e-05, previous alpha=2.795e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=4.015e-05, previous alpha=2.059e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=7.265e-04, previous alpha=2.644e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=3.090e-05, previous alpha=2.862e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 266 iterations, i.e. alpha=9.103e-06, with an active set of 222 regressors, and the smallest cholesky pivot element being 2.356e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 317 iterations, i.e. alpha=3.342e-06, with an active set of 253 regressors, and the smallest cholesky pivot element being 9.771e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 319 iterations, alpha=3.300e-06, previous alpha=3.226e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.781e-03, previous alpha=2.761e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=5.334e-04, previous alpha=2.276e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 352 iterations, alpha=2.787e-04, previous alpha=1.793e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 352 iterations, alpha=7.632e-04, previous alpha=3.238e-06, with an active set of 261 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=4.436e-04, previous alpha=2.160e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=4.730e-05, previous alpha=2.666e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.874e-04, previous alpha=2.954e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.112e-04, previous alpha=2.787e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 335 iterations, i.e. alpha=2.161e-06, with an active set of 257 regressors, and the smallest cholesky pivot element being 2.980e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.123e-04, previous alpha=1.603e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 272 iterations, i.e. alpha=8.785e-06, with an active set of 222 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=2.427e-05, previous alpha=3.195e-06, with an active set of 249 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 326 iterations, i.e. alpha=3.057e-06, with an active set of 252 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 329 iterations, alpha=2.827e-06, previous alpha=2.746e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=2.198e-04, previous alpha=2.513e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 356 iterations, alpha=2.825e-04, previous alpha=1.807e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 351 iterations, alpha=7.285e-04, previous alpha=3.296e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=2.551e-04, previous alpha=2.161e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=6.826e-05, previous alpha=3.567e-06, with an active set of 244 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.985e-05, previous alpha=2.099e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=7.497e-05, previous alpha=2.926e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.922e-04, previous alpha=2.705e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 274 iterations, i.e. alpha=7.425e-06, with an active set of 232 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 303 iterations, i.e. alpha=4.557e-06, with an active set of 251 regressors, and the smallest cholesky pivot element being 2.788e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 304 iterations, i.e. alpha=4.176e-06, with an active set of 252 regressors, and the smallest cholesky pivot element being 2.788e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 305 iterations, alpha=4.121e-06, previous alpha=4.108e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=1.417e-04, previous alpha=2.865e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=9.839e-05, previous alpha=2.419e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=1.041e-03, previous alpha=2.438e-06, with an active set of 262 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=2.657e-04, previous alpha=2.213e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.653e-04, previous alpha=3.296e-06, with an active set of 251 regressors.
#   ConvergenceWarning)

# %%
output_df
# Out:
#                      Dropped                    RMSE          Diff from Base
# 0                         ()  0.10398725860824831191  0.00000000000000000000
# 1             ('TotalBath',)  0.10402985969827177604  0.00004260109002346413
# 2              ('FullBath',)  0.10441193560675399166  0.00042467699850567975
# 3  ('TotalBath', 'FullBath')  0.10547436975330100328  0.00148711114505269137

# %% [markdown]
# The gain by dropping both of these isn't big enough to consider dropping a predictor that we'd consider strong by hedonic reasoning.

# %%
drop_cands = ['MasVnrArea', 'MasVnrAreaLin']

# %%
col_drop_results_df = pd.DataFrame(dtype = 'float64')
count = 0
for L in range(0, len(drop_cands)+1):
        for subset in itertools.combinations(drop_cands, L):
                drop_cols = list(subset)
                col_drop_results_df.loc[count, 'Dropped'] = str(subset)
                x_train = train_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                x_validation = validation_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                lr.fit(x_train, y_train)
                y_pred = lr.predict(x_validation)
                error = rmse(y_validation, y_pred)
                col_drop_results_df.loc[count, 'RMSE'] = error
                col_drop_results_df.loc[count, 'Diff from Base'] = error - baseline                
                count += 1
output_df = col_drop_results_df.sort_values(['RMSE'])
# Out:
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.975e-05, previous alpha=2.666e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.550e-04, previous alpha=2.954e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 304 iterations, i.e. alpha=4.659e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 313 iterations, i.e. alpha=4.105e-06, with an active set of 245 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 313 iterations, i.e. alpha=4.078e-06, with an active set of 245 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 314 iterations, alpha=4.105e-06, previous alpha=4.014e-06, with an active set of 245 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=9.051e-05, previous alpha=2.787e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 272 iterations, i.e. alpha=8.900e-06, with an active set of 222 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 279 iterations, i.e. alpha=7.846e-06, with an active set of 225 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 300 iterations, i.e. alpha=5.324e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 300 iterations, i.e. alpha=5.211e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 304 iterations, alpha=5.264e-06, previous alpha=5.057e-06, with an active set of 245 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=4.863e-04, previous alpha=3.178e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=1.201e-04, previous alpha=2.513e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 356 iterations, alpha=2.799e-04, previous alpha=1.807e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 351 iterations, alpha=6.302e-04, previous alpha=3.296e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=6.365e-05, previous alpha=2.068e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=4.730e-05, previous alpha=2.687e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.875e-04, previous alpha=2.871e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 318 iterations, i.e. alpha=4.302e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.202e-04, previous alpha=2.958e-06, with an active set of 249 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.062e-05, previous alpha=2.162e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 269 iterations, i.e. alpha=9.095e-06, with an active set of 219 regressors, and the smallest cholesky pivot element being 2.356e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 293 iterations, i.e. alpha=6.165e-06, with an active set of 237 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 295 iterations, i.e. alpha=5.641e-06, with an active set of 239 regressors, and the smallest cholesky pivot element being 9.996e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 296 iterations, alpha=5.884e-06, previous alpha=5.636e-06, with an active set of 239 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=1.272e-04, previous alpha=3.164e-06, with an active set of 250 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=2.198e-04, previous alpha=2.518e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 352 iterations, alpha=5.887e-04, previous alpha=1.980e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 351 iterations, alpha=7.285e-04, previous alpha=3.296e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=8.388e-04, previous alpha=2.020e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 305 iterations, i.e. alpha=4.705e-06, with an active set of 239 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 310 iterations, i.e. alpha=4.333e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 311 iterations, alpha=4.333e-06, previous alpha=4.238e-06, with an active set of 242 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=3.974e-05, previous alpha=2.704e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.947e-04, previous alpha=2.741e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.731e-04, previous alpha=2.783e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=2.421e-05, previous alpha=3.137e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=2.198e-04, previous alpha=2.513e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 272 iterations, i.e. alpha=8.785e-06, with an active set of 222 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 279 iterations, i.e. alpha=7.846e-06, with an active set of 225 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 299 iterations, i.e. alpha=5.323e-06, with an active set of 241 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 299 iterations, i.e. alpha=5.207e-06, with an active set of 241 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 302 iterations, alpha=5.260e-06, previous alpha=5.106e-06, with an active set of 243 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=4.368e-05, previous alpha=2.358e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 351 iterations, alpha=7.285e-04, previous alpha=3.296e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=2.551e-04, previous alpha=2.054e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=7.571e-05, previous alpha=2.687e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 308 iterations, i.e. alpha=4.783e-06, with an active set of 238 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=8.702e-05, previous alpha=2.988e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 329 iterations, i.e. alpha=2.609e-06, with an active set of 245 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.112e-04, previous alpha=2.788e-06, with an active set of 250 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=4.014e-05, previous alpha=2.159e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=4.864e-04, previous alpha=3.311e-06, with an active set of 250 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 269 iterations, i.e. alpha=9.095e-06, with an active set of 219 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 293 iterations, i.e. alpha=6.165e-06, with an active set of 237 regressors, and the smallest cholesky pivot element being 2.788e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 296 iterations, alpha=5.884e-06, previous alpha=5.641e-06, with an active set of 239 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=2.198e-04, previous alpha=2.527e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 353 iterations, alpha=1.232e-03, previous alpha=1.799e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 351 iterations, alpha=7.359e-04, previous alpha=3.296e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=4.536e-04, previous alpha=2.100e-06, with an active set of 248 regressors.
#   ConvergenceWarning)

# %%
output_df
# Out:
#                            Dropped                    RMSE  \
# 3  ('MasVnrArea', 'MasVnrAreaLin')  0.10398346802235253206
# 0                               ()  0.10398725860824831191
# 2               ('MasVnrAreaLin',)  0.10408960927660004803
# 1                  ('MasVnrArea',)  0.10506357494678844611
#
#            Diff from Base
# 3 -0.00000379058589577985
# 0  0.00000000000000000000
# 2  0.00010235066835173612
# 1  0.00107631633854013420

# %%
drop_cands = ['LogGrLivArea', 'GrLivArea', 'TotalHouseArea', 'LivArea', 'LivAreaWt', 'AreasSum']

# %%
col_drop_results_df = pd.DataFrame(dtype = 'float64')
count = 0
for L in range(0, len(drop_cands)+1):
        for subset in itertools.combinations(drop_cands, L):
                drop_cols = list(subset)
                col_drop_results_df.loc[count, 'Dropped'] = str(subset)
                x_train = train_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                x_validation = validation_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                lr.fit(x_train, y_train)
                y_pred = lr.predict(x_validation)
                error = rmse(y_validation, y_pred)
                col_drop_results_df.loc[count, 'RMSE'] = error
                col_drop_results_df.loc[count, 'Diff from Base'] = error - baseline                
                count += 1
output_df = col_drop_results_df.sort_values(['RMSE'])
# Out:
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=9.051e-05, previous alpha=2.787e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.975e-05, previous alpha=2.666e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 304 iterations, i.e. alpha=4.659e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 313 iterations, i.e. alpha=4.105e-06, with an active set of 245 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 313 iterations, i.e. alpha=4.078e-06, with an active set of 245 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 314 iterations, alpha=4.105e-06, previous alpha=4.014e-06, with an active set of 245 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.550e-04, previous alpha=2.954e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=4.863e-04, previous alpha=3.178e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 272 iterations, i.e. alpha=8.900e-06, with an active set of 222 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 279 iterations, i.e. alpha=7.846e-06, with an active set of 225 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=1.201e-04, previous alpha=2.513e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 300 iterations, i.e. alpha=5.324e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 300 iterations, i.e. alpha=5.211e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 304 iterations, alpha=5.264e-06, previous alpha=5.057e-06, with an active set of 245 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 356 iterations, alpha=2.799e-04, previous alpha=1.807e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 351 iterations, alpha=6.302e-04, previous alpha=3.296e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=6.365e-05, previous alpha=2.068e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=4.144e-04, previous alpha=2.712e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 303 iterations, i.e. alpha=4.565e-06, with an active set of 235 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=4.008e-04, previous alpha=2.621e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.549e-04, previous alpha=2.963e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.463e-04, previous alpha=1.729e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=2.427e-05, previous alpha=3.195e-06, with an active set of 249 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.785e-04, previous alpha=3.384e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=1.200e-04, previous alpha=2.574e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 277 iterations, i.e. alpha=8.405e-06, with an active set of 221 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 316 iterations, i.e. alpha=4.043e-06, with an active set of 248 regressors, and the smallest cholesky pivot element being 2.788e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 317 iterations, alpha=4.006e-06, previous alpha=3.976e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=3.981e-04, previous alpha=2.462e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=2.551e-04, previous alpha=2.170e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.237e-05, previous alpha=3.631e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=4.038e-05, previous alpha=2.269e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.035e-04, previous alpha=3.243e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.710e-04, previous alpha=3.591e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 267 iterations, i.e. alpha=7.930e-06, with an active set of 225 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 269 iterations, i.e. alpha=7.810e-06, with an active set of 227 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.781e-03, previous alpha=2.773e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 275 iterations, alpha=7.246e-06, previous alpha=7.176e-06, with an active set of 232 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=1.954e-04, previous alpha=2.612e-06, with an active set of 261 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=9.535e-06, previous alpha=2.799e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=2.121e-03, previous alpha=2.448e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=4.900e-04, previous alpha=3.302e-06, with an active set of 261 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=1.116e-04, previous alpha=2.692e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.194e-04, previous alpha=2.835e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.047e-04, previous alpha=3.138e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.055e-05, previous alpha=1.750e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=3.232e-04, previous alpha=2.961e-06, with an active set of 247 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 275 iterations, i.e. alpha=7.589e-06, with an active set of 227 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 306 iterations, i.e. alpha=4.446e-06, with an active set of 250 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 307 iterations, alpha=4.399e-06, previous alpha=4.327e-06, with an active set of 250 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=4.343e-04, previous alpha=2.249e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=3.970e-05, previous alpha=2.642e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.855e-04, previous alpha=3.607e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.069e-03, previous alpha=2.198e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=3.929e-04, previous alpha=3.399e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 300 iterations, i.e. alpha=4.914e-06, with an active set of 240 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 323 iterations, alpha=3.021e-06, previous alpha=3.021e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=9.047e-05, previous alpha=3.317e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.249e-04, previous alpha=3.097e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=3.971e-04, previous alpha=2.661e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 300 iterations, i.e. alpha=5.355e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 2.356e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 304 iterations, alpha=5.174e-06, previous alpha=5.035e-06, with an active set of 245 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=2.932e-04, previous alpha=2.261e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=6.639e-05, previous alpha=3.212e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=2.193e-04, previous alpha=3.046e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=4.436e-04, previous alpha=2.164e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.851e-04, previous alpha=2.896e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=4.508e-05, previous alpha=2.163e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.513e-05, previous alpha=2.655e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.104e-05, previous alpha=2.506e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 271 iterations, i.e. alpha=8.158e-06, with an active set of 223 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 310 iterations, i.e. alpha=4.298e-06, with an active set of 250 regressors, and the smallest cholesky pivot element being 7.955e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 312 iterations, alpha=4.117e-06, previous alpha=4.089e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=1.953e-04, previous alpha=2.640e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=2.005e-03, previous alpha=2.781e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=9.197e-05, previous alpha=3.186e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.092e-04, previous alpha=3.296e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=4.436e-04, previous alpha=2.140e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 350 iterations, alpha=7.111e-04, previous alpha=2.592e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 303 iterations, i.e. alpha=5.194e-06, with an active set of 241 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=8.506e-05, previous alpha=2.709e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=4.495e-05, previous alpha=2.021e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=4.110e-04, previous alpha=2.915e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=8.046e-04, previous alpha=2.762e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 308 iterations, i.e. alpha=5.094e-06, with an active set of 246 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 322 iterations, i.e. alpha=3.482e-06, with an active set of 252 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.836e-04, previous alpha=2.286e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=1.012e-04, previous alpha=1.904e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=3.493e-04, previous alpha=2.880e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=7.803e-04, previous alpha=3.028e-06, with an active set of 263 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=9.944e-06, previous alpha=2.068e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=6.861e-05, previous alpha=3.263e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.035e-04, previous alpha=3.146e-06, with an active set of 247 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=6.796e-04, previous alpha=2.173e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=2.045e-04, previous alpha=3.321e-06, with an active set of 250 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 302 iterations, i.e. alpha=3.839e-06, with an active set of 248 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 303 iterations, i.e. alpha=3.719e-06, with an active set of 249 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.954e-03, previous alpha=2.773e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=1.199e-04, previous alpha=2.630e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=4.962e-04, previous alpha=1.579e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=4.127e-04, previous alpha=2.777e-06, with an active set of 249 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=6.018e-05, previous alpha=4.571e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=1.756e-04, previous alpha=2.655e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 316 iterations, i.e. alpha=3.956e-06, with an active set of 240 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=7.611e-05, previous alpha=2.617e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=6.937e-06, previous alpha=1.784e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.726e-04, previous alpha=2.581e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=9.601e-05, previous alpha=3.415e-06, with an active set of 250 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.797e-04, previous alpha=3.285e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 312 iterations, i.e. alpha=3.957e-06, with an active set of 248 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 315 iterations, i.e. alpha=3.818e-06, with an active set of 249 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.047e-03, previous alpha=1.887e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=2.566e-05, previous alpha=2.156e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=9.186e-06, previous alpha=2.323e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=1.503e-04, previous alpha=4.246e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=2.453e-04, previous alpha=2.393e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 299 iterations, i.e. alpha=4.811e-06, with an active set of 237 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 300 iterations, i.e. alpha=4.780e-06, with an active set of 238 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 300 iterations, i.e. alpha=4.749e-06, with an active set of 238 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=6.854e-05, previous alpha=3.232e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=9.614e-05, previous alpha=3.314e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=3.428e-04, previous alpha=2.865e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 335 iterations, i.e. alpha=2.390e-06, with an active set of 251 regressors, and the smallest cholesky pivot element being 3.942e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 337 iterations, alpha=2.287e-06, previous alpha=2.227e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 276 iterations, i.e. alpha=8.213e-06, with an active set of 224 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 283 iterations, alpha=7.364e-06, previous alpha=7.262e-06, with an active set of 230 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=6.159e-04, previous alpha=2.827e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=5.334e-04, previous alpha=2.396e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=7.502e-05, previous alpha=3.222e-06, with an active set of 250 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=5.607e-04, previous alpha=2.195e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=4.991e-06, previous alpha=3.165e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 350 iterations, alpha=7.696e-05, previous alpha=1.994e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 304 iterations, i.e. alpha=4.722e-06, with an active set of 238 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.168e-05, previous alpha=2.548e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=2.776e-04, previous alpha=2.042e-06, with an active set of 250 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=5.425e-05, previous alpha=2.821e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 322 iterations, i.e. alpha=3.490e-06, with an active set of 248 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 323 iterations, i.e. alpha=3.428e-06, with an active set of 249 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=4.863e-04, previous alpha=3.136e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 327 iterations, alpha=3.134e-06, previous alpha=3.088e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=6.020e-04, previous alpha=2.727e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=9.203e-05, previous alpha=3.105e-06, with an active set of 250 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=4.508e-04, previous alpha=3.507e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=4.595e-04, previous alpha=2.192e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=4.878e-04, previous alpha=3.541e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 306 iterations, i.e. alpha=5.305e-06, with an active set of 236 regressors, and the smallest cholesky pivot element being 3.650e-08
#   ConvergenceWarning)
# ...
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 207 iterations, i.e. alpha=2.706e-05, with an active set of 177 regressors, and the smallest cholesky pivot element being 2.356e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=1.250e-04, previous alpha=2.920e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 226 iterations, i.e. alpha=2.114e-05, with an active set of 192 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 232 iterations, alpha=1.925e-05, previous alpha=1.923e-05, with an active set of 197 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 340 iterations, alpha=1.482e-04, previous alpha=3.002e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=3.844e-05, previous alpha=4.116e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 340 iterations, alpha=1.266e-04, previous alpha=5.164e-06, with an active set of 245 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=2.250e-04, previous alpha=2.473e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=1.245e-05, previous alpha=3.123e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 281 iterations, i.e. alpha=7.650e-06, with an active set of 225 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 340 iterations, alpha=1.746e-04, previous alpha=2.498e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=2.967e-04, previous alpha=3.185e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 340 iterations, alpha=2.003e-04, previous alpha=2.616e-06, with an active set of 247 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 168 iterations, i.e. alpha=4.911e-05, with an active set of 152 regressors, and the smallest cholesky pivot element being 2.356e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 227 iterations, i.e. alpha=1.882e-05, with an active set of 187 regressors, and the smallest cholesky pivot element being 2.356e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 227 iterations, i.e. alpha=1.881e-05, with an active set of 187 regressors, and the smallest cholesky pivot element being 2.356e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 239 iterations, alpha=1.655e-05, previous alpha=1.634e-05, with an active set of 198 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 340 iterations, alpha=1.858e-04, previous alpha=2.356e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=2.912e-04, previous alpha=2.231e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=1.256e-04, previous alpha=3.856e-06, with an active set of 250 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 340 iterations, alpha=4.912e-04, previous alpha=3.743e-06, with an active set of 249 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 340 iterations, alpha=3.647e-05, previous alpha=2.195e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 340 iterations, alpha=5.933e-06, previous alpha=2.894e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 311 iterations, i.e. alpha=4.693e-06, with an active set of 239 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 350 iterations, alpha=2.918e-04, previous alpha=3.083e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=4.991e-05, previous alpha=3.293e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=1.015e-05, previous alpha=2.640e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=1.126e-04, previous alpha=2.424e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=1.282e-04, previous alpha=3.298e-06, with an active set of 246 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=2.647e-04, previous alpha=3.470e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 314 iterations, i.e. alpha=4.401e-06, with an active set of 244 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=4.404e-06, previous alpha=3.114e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=2.513e-05, previous alpha=1.986e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.008e-04, previous alpha=2.485e-06, with an active set of 249 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 339 iterations, alpha=3.089e-05, previous alpha=3.085e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 302 iterations, i.e. alpha=6.478e-06, with an active set of 226 regressors, and the smallest cholesky pivot element being 5.373e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 338 iterations, alpha=1.127e-04, previous alpha=3.820e-06, with an active set of 241 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 339 iterations, alpha=3.181e-04, previous alpha=3.001e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=3.949e-04, previous alpha=3.453e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 340 iterations, alpha=1.969e-04, previous alpha=2.600e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 259 iterations, i.e. alpha=1.255e-05, with an active set of 205 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 262 iterations, i.e. alpha=1.249e-05, with an active set of 208 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 263 iterations, alpha=1.248e-05, previous alpha=1.236e-05, with an active set of 208 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=3.176e-04, previous alpha=2.423e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 339 iterations, i.e. alpha=4.166e-06, with an active set of 247 regressors, and the smallest cholesky pivot element being 9.306e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=8.981e-05, previous alpha=3.858e-06, with an active set of 250 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=2.491e-04, previous alpha=2.163e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=3.388e-05, previous alpha=3.487e-06, with an active set of 253 regressors.
#   ConvergenceWarning)

# %%
output_df
# Out:
#                                                                                 Dropped  \
# 59             ('LogGrLivArea', 'GrLivArea', 'TotalHouseArea', 'LivAreaWt', 'AreasSum')
# 58               ('LogGrLivArea', 'GrLivArea', 'TotalHouseArea', 'LivArea', 'AreasSum')
# 44                          ('LogGrLivArea', 'GrLivArea', 'TotalHouseArea', 'AreasSum')
# 47                               ('LogGrLivArea', 'GrLivArea', 'LivAreaWt', 'AreasSum')
# 24                                           ('LogGrLivArea', 'GrLivArea', 'LivAreaWt')
# 22                                      ('LogGrLivArea', 'GrLivArea', 'TotalHouseArea')
# 43                         ('LogGrLivArea', 'GrLivArea', 'TotalHouseArea', 'LivAreaWt')
# 0                                                                                    ()
# 12                                                      ('GrLivArea', 'TotalHouseArea')
# 1                                                                     ('LogGrLivArea',)
# 3                                                                   ('TotalHouseArea',)
# 16                                                        ('TotalHouseArea', 'LivArea')
# 8                                                    ('LogGrLivArea', 'TotalHouseArea')
# 26                                        ('LogGrLivArea', 'TotalHouseArea', 'LivArea')
# 13                                                             ('GrLivArea', 'LivArea')
# 23                                             ('LogGrLivArea', 'GrLivArea', 'LivArea')
# 49                            ('LogGrLivArea', 'TotalHouseArea', 'LivArea', 'AreasSum')
# 7                                                         ('LogGrLivArea', 'GrLivArea')
# 50                          ('LogGrLivArea', 'TotalHouseArea', 'LivAreaWt', 'AreasSum')
# 46                                 ('LogGrLivArea', 'GrLivArea', 'LivArea', 'AreasSum')
# 10                                                        ('LogGrLivArea', 'LivAreaWt')
# 36                                                 ('GrLivArea', 'LivArea', 'AreasSum')
# 27                                      ('LogGrLivArea', 'TotalHouseArea', 'LivAreaWt')
# 28                                       ('LogGrLivArea', 'TotalHouseArea', 'AreasSum')
# 15                                                            ('GrLivArea', 'AreasSum')
# 34                                          ('GrLivArea', 'TotalHouseArea', 'AreasSum')
# 4                                                                          ('LivArea',)
# 17                                                      ('TotalHouseArea', 'LivAreaWt')
# 5                                                                        ('LivAreaWt',)
# 18                                                       ('TotalHouseArea', 'AreasSum')
# ..                                                                                  ...
# 9                                                           ('LogGrLivArea', 'LivArea')
# 40                                          ('TotalHouseArea', 'LivAreaWt', 'AreasSum')
# 14                                                           ('GrLivArea', 'LivAreaWt')
# 20                                                              ('LivArea', 'AreasSum')
# 39                                            ('TotalHouseArea', 'LivArea', 'AreasSum')
# 32                                           ('GrLivArea', 'TotalHouseArea', 'LivArea')
# 25                                            ('LogGrLivArea', 'GrLivArea', 'AreasSum')
# 31                                            ('LogGrLivArea', 'LivAreaWt', 'AreasSum')
# 21                                                            ('LivAreaWt', 'AreasSum')
# 33                                         ('GrLivArea', 'TotalHouseArea', 'LivAreaWt')
# 37                                               ('GrLivArea', 'LivAreaWt', 'AreasSum')
# 29                                             ('LogGrLivArea', 'LivArea', 'LivAreaWt')
# 19                                                             ('LivArea', 'LivAreaWt')
# 38                                           ('TotalHouseArea', 'LivArea', 'LivAreaWt')
# 54                             ('GrLivArea', 'TotalHouseArea', 'LivAreaWt', 'AreasSum')
# 48                           ('LogGrLivArea', 'TotalHouseArea', 'LivArea', 'LivAreaWt')
# 30                                              ('LogGrLivArea', 'LivArea', 'AreasSum')
# 56                               ('TotalHouseArea', 'LivArea', 'LivAreaWt', 'AreasSum')
# 51                                 ('LogGrLivArea', 'LivArea', 'LivAreaWt', 'AreasSum')
# 63  ('LogGrLivArea', 'GrLivArea', 'TotalHouseArea', 'LivArea', 'LivAreaWt', 'AreasSum')
# 11                                                         ('LogGrLivArea', 'AreasSum')
# 35                                                ('GrLivArea', 'LivArea', 'LivAreaWt')
# 61               ('LogGrLivArea', 'TotalHouseArea', 'LivArea', 'LivAreaWt', 'AreasSum')
# 60                    ('LogGrLivArea', 'GrLivArea', 'LivArea', 'LivAreaWt', 'AreasSum')
# 52                              ('GrLivArea', 'TotalHouseArea', 'LivArea', 'LivAreaWt')
# 42                           ('LogGrLivArea', 'GrLivArea', 'TotalHouseArea', 'LivArea')
# 45                                ('LogGrLivArea', 'GrLivArea', 'LivArea', 'LivAreaWt')
# 41                                                 ('LivArea', 'LivAreaWt', 'AreasSum')
# 55                                    ('GrLivArea', 'LivArea', 'LivAreaWt', 'AreasSum')
# 62                  ('GrLivArea', 'TotalHouseArea', 'LivArea', 'LivAreaWt', 'AreasSum')
#
#                       RMSE          Diff from Base
# 59  0.10360817226279898928 -0.00037908634544932263
# 58  0.10365739713993106508 -0.00032986146831724683
# 44  0.10366177279650089227 -0.00032548581174741964
# 47  0.10372816811309794327 -0.00025909049515036864
# 24  0.10375766254330309746 -0.00022959606494521445
# 22  0.10386160988924549031 -0.00012564871900282160
# 43  0.10387194813726273457 -0.00011531047098557734
# 0   0.10398725860824831191  0.00000000000000000000
# 12  0.10407926191761297796  0.00009200330936466605
# 1   0.10408960927660008966  0.00010235066835177775
# 3   0.10410761077751792825  0.00012035216926961634
# 16  0.10411809851981361497  0.00013083991156530306
# 8   0.10412050818482246339  0.00013324957657415148
# 26  0.10412487234032698213  0.00013761373207867023
# 13  0.10416560600721198881  0.00017834739896367691
# 23  0.10416561358007800364  0.00017835497182969173
# 49  0.10417290669648310297  0.00018564808823479106
# 7   0.10417492460246387254  0.00018766599421556063
# 50  0.10417920782716535988  0.00019194921891704797
# 46  0.10417992469826574398  0.00019266609001743207
# 10  0.10418462959106428167  0.00019737098281596976
# 36  0.10418644664096815555  0.00019918803271984364
# 27  0.10419687379954083173  0.00020961519129251982
# 28  0.10420759411840781195  0.00022033551015950004
# 15  0.10421159280299636951  0.00022433419474805760
# 34  0.10422252918880409167  0.00023527058055577976
# 4   0.10422364000216709223  0.00023638139391878032
# 17  0.10422597438070194120  0.00023871577245362929
# 5   0.10422672590267703652  0.00023946729442872461
# 18  0.10422883393882245717  0.00024157533057414526
# ..                     ...                     ...
# 9   0.10427512145976039482  0.00028786285151208291
# 40  0.10434034332905436915  0.00035308472080605724
# 14  0.10434713879030162176  0.00035988018205330985
# 20  0.10435990210953828561  0.00037264350128997370
# 39  0.10437815317115158031  0.00039089456290326841
# 32  0.10438271601360607499  0.00039545740535776308
# 25  0.10438472259963191280  0.00039746399138360089
# 31  0.10444170015875824109  0.00045444155050992918
# 21  0.10444184326927423434  0.00045458466102592243
# 33  0.10444768705577663070  0.00046042844752831880
# 37  0.10453657891323016316  0.00054932030498185125
# 29  0.10455466289113332645  0.00056740428288501454
# 19  0.10456698716906072388  0.00057972856081241197
# 38  0.10460140084143053352  0.00061414223318222161
# 54  0.10463229827834970298  0.00064503967010139107
# 48  0.10464675085587646364  0.00065949224762815173
# 30  0.10467821005234199949  0.00069095144409368758
# 56  0.10469989647879897332  0.00071263787055066141
# 51  0.10471292591785395787  0.00072566730960564596
# 63  0.10476285297091926518  0.00077559436267095327
# 11  0.10476525526086299944  0.00077799665261468753
# 35  0.10489724555035961906  0.00090998694211130715
# 61  0.10495386981992885223  0.00096661121168054032
# 60  0.10497520576867123976  0.00098794716042292785
# 52  0.10508416104696290116  0.00109690243871458926
# 42  0.10512943413795025616  0.00114217552970194425
# 45  0.10520528492525503539  0.00121802631700672348
# 41  0.10557248422097965934  0.00158522561273134743
# 55  0.10575944370197880307  0.00177218509373049116
# 62  0.10619934679798445631  0.00221208818973614441
#
# [64 rows x 3 columns]
