# %% [markdown]
# # Feature Selection on the 111101011 dataset

# %% [markdown]
# In this notebook we examine the result of dropping subsets of features that are linearly dependent or correlated to some degree.  We're specifically working on the dataset formed by dropping (31, 496, 524, 534, 917, 1183, 1299), since that resulted in the 4th lowest validation error.

# %%
import itertools
import numpy as np
import pandas as pd

pd.set_option('display.precision',20)
pd.set_option('display.max_colwidth',100)

from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, cross_val_predict, KFold, cross_val_score, \
                                    GridSearchCV, RandomizedSearchCV, ShuffleSplit 
from time import time
from scipy.stats import randint as sp_randint

import matplotlib.pylab as plt
from matplotlib.pylab import rcParams
from matplotlib import pyplot
rcParams['figure.figsize'] = 12, 4
# %matplotlib inline

# %%
# def to compare goodness of fit on training set
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
# Cross-validation sets
kfold = KFold(n_splits=10, random_state=7)

# We are using LassoLarsCV as part of our metric
lr = linear_model.LassoLarsCV(verbose=False, max_iter=5000,precompute='auto', cv=kfold, max_n_alphas=1000, n_jobs=-1)

# %%
df = pd.read_csv("./input/train_tidy_111101011.csv")

# %%
ss = ShuffleSplit(n_splits=1, test_size=0.20, random_state=573)

# %%
X = df.values

# %%
for train_idx, validation_idx in ss.split(X):
    train_df = df.iloc[train_idx]
    validation_df = df.iloc[validation_idx]

# %% [markdown]
# We will establish a baseline by keeping all features.

# %%
y_validation = validation_df['SalePrice'].values
x_validation = validation_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'],axis=1).values
y_train = train_df['SalePrice'].values
x_train = train_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'],axis=1).values
lr.fit(x_train, y_train)
y_pred = lr.predict(x_validation)
baseline = rmse(y_validation, y_pred)
baseline
# Out:
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 316 iterations, i.e. alpha=4.700e-06, with an active set of 238 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=5.193e-04, previous alpha=2.280e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.966e-04, previous alpha=2.735e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=2.184e-04, previous alpha=2.490e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.262e-04, previous alpha=2.377e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 236 iterations, i.e. alpha=1.691e-05, with an active set of 202 regressors, and the smallest cholesky pivot element being 2.788e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 237 iterations, i.e. alpha=1.686e-05, with an active set of 203 regressors, and the smallest cholesky pivot element being 2.788e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 239 iterations, alpha=1.646e-05, previous alpha=1.604e-05, with an active set of 204 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.003e-04, previous alpha=2.738e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=1.053e-03, previous alpha=4.008e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=6.580e-06, previous alpha=1.647e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=3.549e-04, previous alpha=1.972e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=2.013e-04, previous alpha=2.888e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# 0.10515807312252047

# %% [markdown]
# ## Features

# %% [markdown]
# We have a collection of Features, some of which were identified to be of potentially low-quality in predicting the response, others of which are known to be highly correlated with other Features.  We want to identify subsets of features that we can drop to improve the regression.

# %%
drop_cands = [
    'LotFrontage', 'LotArea', 'BsmtUnfSF', 'LowQualFinSF',
    'LogGrLivArea', 
    'GrLivArea', 'TotalHouseArea', 'LivArea', 'LivAreaWt', 'AllSizesSum', 'AllSizesSumLin', 'AreasSum',
    'X1stFlrSF','X1stLin', 'X2ndFlrSF', 'X2ndLin',
    'TotalBath', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
    'Age', 'AgeLin', 'RemodAgeLin','RemodAge',
    'MasVnrArea', 'MasVnrAreaLin',
    'DeckPorchLin','WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', 'X3SsnPorch', 'ScreenPorch'
]

# %%
corr_df = df[drop_cands].corr()

# %%
corr_df[corr_df > 0.75]
# Out:
#                 LotFrontage                 LotArea  BsmtUnfSF  LowQualFinSF  \
# LotFrontage             1.0                     NaN        NaN           NaN
# LotArea                 NaN  1.00000000000000000000        NaN           NaN
# BsmtUnfSF               NaN                     NaN        1.0           NaN
# LowQualFinSF            NaN                     NaN        NaN           1.0
# LogGrLivArea            NaN                     NaN        NaN           NaN
# GrLivArea               NaN                     NaN        NaN           NaN
# TotalHouseArea          NaN                     NaN        NaN           NaN
# LivArea                 NaN                     NaN        NaN           NaN
# LivAreaWt               NaN                     NaN        NaN           NaN
# AllSizesSum             NaN  0.98606372397245245498        NaN           NaN
# AllSizesSumLin          NaN                     NaN        NaN           NaN
# AreasSum                NaN                     NaN        NaN           NaN
# X1stFlrSF               NaN                     NaN        NaN           NaN
# X1stLin                 NaN                     NaN        NaN           NaN
# X2ndFlrSF               NaN                     NaN        NaN           NaN
# X2ndLin                 NaN                     NaN        NaN           NaN
# TotalBath               NaN                     NaN        NaN           NaN
# BsmtFullBath            NaN                     NaN        NaN           NaN
# BsmtHalfBath            NaN                     NaN        NaN           NaN
# FullBath                NaN                     NaN        NaN           NaN
# HalfBath                NaN                     NaN        NaN           NaN
# Age                     NaN                     NaN        NaN           NaN
# AgeLin                  NaN                     NaN        NaN           NaN
# RemodAgeLin             NaN                     NaN        NaN           NaN
# RemodAge                NaN                     NaN        NaN           NaN
# MasVnrArea              NaN                     NaN        NaN           NaN
# MasVnrAreaLin           NaN                     NaN        NaN           NaN
# DeckPorchLin            NaN                     NaN        NaN           NaN
# WoodDeckSF              NaN                     NaN        NaN           NaN
# OpenPorchSF             NaN                     NaN        NaN           NaN
# EnclosedPorch           NaN                     NaN        NaN           NaN
# X3SsnPorch              NaN                     NaN        NaN           NaN
# ScreenPorch             NaN                     NaN        NaN           NaN
#
#                           LogGrLivArea               GrLivArea  \
# LotFrontage                        NaN                     NaN
# LotArea                            NaN                     NaN
# BsmtUnfSF                          NaN                     NaN
# LowQualFinSF                       NaN                     NaN
# LogGrLivArea    1.00000000000000000000  0.97572734790673321115
# GrLivArea       0.97572734790673321115  1.00000000000000000000
# TotalHouseArea  0.86058937220902298471  0.83559555857857792383
# LivArea         0.76373332501539625827  0.76725195583060601390
# LivAreaWt       0.91883982161090238527  0.91377560660947887428
# AllSizesSum                        NaN                     NaN
# AllSizesSumLin                     NaN                     NaN
# AreasSum        0.83185505671546178252  0.81989666984062914423
# X1stFlrSF                          NaN                     NaN
# X1stLin                            NaN                     NaN
# X2ndFlrSF                          NaN                     NaN
# X2ndLin                            NaN                     NaN
# TotalBath                          NaN                     NaN
# BsmtFullBath                       NaN                     NaN
# BsmtHalfBath                       NaN                     NaN
# FullBath                           NaN                     NaN
# HalfBath                           NaN                     NaN
# Age                                NaN                     NaN
# AgeLin                             NaN                     NaN
# RemodAgeLin                        NaN                     NaN
# RemodAge                           NaN                     NaN
# MasVnrArea                         NaN                     NaN
# MasVnrAreaLin                      NaN                     NaN
# DeckPorchLin                       NaN                     NaN
# WoodDeckSF                         NaN                     NaN
# OpenPorchSF                        NaN                     NaN
# EnclosedPorch                      NaN                     NaN
# X3SsnPorch                         NaN                     NaN
# ScreenPorch                        NaN                     NaN
#
#                         TotalHouseArea                 LivArea  \
# LotFrontage                        NaN                     NaN
# LotArea                            NaN                     NaN
# BsmtUnfSF                          NaN                     NaN
# LowQualFinSF                       NaN                     NaN
# LogGrLivArea    0.86058937220902298471  0.76373332501539625827
# GrLivArea       0.83559555857857792383  0.76725195583060601390
# TotalHouseArea  1.00000000000000000000  0.80249169125840447148
# LivArea         0.80249169125840447148  1.00000000000000000000
# LivAreaWt       0.87595423074054235002  0.94575036201415385584
# AllSizesSum                        NaN                     NaN
# AllSizesSumLin                     NaN                     NaN
# AreasSum        0.93233555658687905510  0.79502614267426652273
# X1stFlrSF                          NaN                     NaN
# X1stLin                            NaN                     NaN
# X2ndFlrSF                          NaN                     NaN
# X2ndLin                            NaN                     NaN
# TotalBath                          NaN                     NaN
# BsmtFullBath                       NaN                     NaN
# BsmtHalfBath                       NaN                     NaN
# FullBath                           NaN                     NaN
# HalfBath                           NaN                     NaN
# Age                                NaN                     NaN
# AgeLin                             NaN                     NaN
# RemodAgeLin                        NaN                     NaN
# RemodAge                           NaN                     NaN
# MasVnrArea                         NaN                     NaN
# MasVnrAreaLin                      NaN                     NaN
# DeckPorchLin                       NaN                     NaN
# WoodDeckSF                         NaN                     NaN
# OpenPorchSF                        NaN                     NaN
# EnclosedPorch                      NaN                     NaN
# X3SsnPorch                         NaN                     NaN
# ScreenPorch                        NaN                     NaN
#
#                              LivAreaWt             AllSizesSum     ...       \
# LotFrontage                        NaN                     NaN     ...
# LotArea                            NaN  0.98606372397245245498     ...
# BsmtUnfSF                          NaN                     NaN     ...
# LowQualFinSF                       NaN                     NaN     ...
# LogGrLivArea    0.91883982161090238527                     NaN     ...
# GrLivArea       0.91377560660947887428                     NaN     ...
# TotalHouseArea  0.87595423074054235002                     NaN     ...
# LivArea         0.94575036201415385584                     NaN     ...
# LivAreaWt       1.00000000000000000000                     NaN     ...
# AllSizesSum                        NaN  1.00000000000000000000     ...
# AllSizesSumLin                     NaN                     NaN     ...
# AreasSum        0.86132578116270241964                     NaN     ...
# X1stFlrSF                          NaN                     NaN     ...
# X1stLin                            NaN                     NaN     ...
# X2ndFlrSF                          NaN                     NaN     ...
# X2ndLin                            NaN                     NaN     ...
# TotalBath                          NaN                     NaN     ...
# BsmtFullBath                       NaN                     NaN     ...
# BsmtHalfBath                       NaN                     NaN     ...
# FullBath                           NaN                     NaN     ...
# HalfBath                           NaN                     NaN     ...
# Age                                NaN                     NaN     ...
# AgeLin                             NaN                     NaN     ...
# RemodAgeLin                        NaN                     NaN     ...
# RemodAge                           NaN                     NaN     ...
# MasVnrArea                         NaN                     NaN     ...
# MasVnrAreaLin                      NaN                     NaN     ...
# DeckPorchLin                       NaN                     NaN     ...
# WoodDeckSF                         NaN                     NaN     ...
# OpenPorchSF                        NaN                     NaN     ...
# EnclosedPorch                      NaN                     NaN     ...
# X3SsnPorch                         NaN                     NaN     ...
# ScreenPorch                        NaN                     NaN     ...
#
#                 RemodAgeLin  RemodAge              MasVnrArea  \
# LotFrontage             NaN       NaN                     NaN
# LotArea                 NaN       NaN                     NaN
# BsmtUnfSF               NaN       NaN                     NaN
# LowQualFinSF            NaN       NaN                     NaN
# LogGrLivArea            NaN       NaN                     NaN
# GrLivArea               NaN       NaN                     NaN
# TotalHouseArea          NaN       NaN                     NaN
# LivArea                 NaN       NaN                     NaN
# LivAreaWt               NaN       NaN                     NaN
# AllSizesSum             NaN       NaN                     NaN
# AllSizesSumLin          NaN       NaN                     NaN
# AreasSum                NaN       NaN                     NaN
# X1stFlrSF               NaN       NaN                     NaN
# X1stLin                 NaN       NaN                     NaN
# X2ndFlrSF               NaN       NaN                     NaN
# X2ndLin                 NaN       NaN                     NaN
# TotalBath               NaN       NaN                     NaN
# BsmtFullBath            NaN       NaN                     NaN
# BsmtHalfBath            NaN       NaN                     NaN
# FullBath                NaN       NaN                     NaN
# HalfBath                NaN       NaN                     NaN
# Age                     NaN       NaN                     NaN
# AgeLin                  NaN       NaN                     NaN
# RemodAgeLin             1.0       NaN                     NaN
# RemodAge                NaN       1.0                     NaN
# MasVnrArea              NaN       NaN  1.00000000000000000000
# MasVnrAreaLin           NaN       NaN  0.91131509991048920138
# DeckPorchLin            NaN       NaN                     NaN
# WoodDeckSF              NaN       NaN                     NaN
# OpenPorchSF             NaN       NaN                     NaN
# EnclosedPorch           NaN       NaN                     NaN
# X3SsnPorch              NaN       NaN                     NaN
# ScreenPorch             NaN       NaN                     NaN
#
#                          MasVnrAreaLin  DeckPorchLin  WoodDeckSF  OpenPorchSF  \
# LotFrontage                        NaN           NaN         NaN          NaN
# LotArea                            NaN           NaN         NaN          NaN
# BsmtUnfSF                          NaN           NaN         NaN          NaN
# LowQualFinSF                       NaN           NaN         NaN          NaN
# LogGrLivArea                       NaN           NaN         NaN          NaN
# GrLivArea                          NaN           NaN         NaN          NaN
# TotalHouseArea                     NaN           NaN         NaN          NaN
# LivArea                            NaN           NaN         NaN          NaN
# LivAreaWt                          NaN           NaN         NaN          NaN
# AllSizesSum                        NaN           NaN         NaN          NaN
# AllSizesSumLin                     NaN           NaN         NaN          NaN
# AreasSum                           NaN           NaN         NaN          NaN
# X1stFlrSF                          NaN           NaN         NaN          NaN
# X1stLin                            NaN           NaN         NaN          NaN
# X2ndFlrSF                          NaN           NaN         NaN          NaN
# X2ndLin                            NaN           NaN         NaN          NaN
# TotalBath                          NaN           NaN         NaN          NaN
# BsmtFullBath                       NaN           NaN         NaN          NaN
# BsmtHalfBath                       NaN           NaN         NaN          NaN
# FullBath                           NaN           NaN         NaN          NaN
# HalfBath                           NaN           NaN         NaN          NaN
# Age                                NaN           NaN         NaN          NaN
# AgeLin                             NaN           NaN         NaN          NaN
# RemodAgeLin                        NaN           NaN         NaN          NaN
# RemodAge                           NaN           NaN         NaN          NaN
# MasVnrArea      0.91131509991048920138           NaN         NaN          NaN
# MasVnrAreaLin   1.00000000000000000000           NaN         NaN          NaN
# DeckPorchLin                       NaN           1.0         NaN          NaN
# WoodDeckSF                         NaN           NaN         1.0          NaN
# OpenPorchSF                        NaN           NaN         NaN          1.0
# EnclosedPorch                      NaN           NaN         NaN          NaN
# X3SsnPorch                         NaN           NaN         NaN          NaN
# ScreenPorch                        NaN           NaN         NaN          NaN
#
#                 EnclosedPorch  X3SsnPorch  ScreenPorch
# LotFrontage               NaN         NaN          NaN
# LotArea                   NaN         NaN          NaN
# BsmtUnfSF                 NaN         NaN          NaN
# LowQualFinSF              NaN         NaN          NaN
# LogGrLivArea              NaN         NaN          NaN
# GrLivArea                 NaN         NaN          NaN
# TotalHouseArea            NaN         NaN          NaN
# LivArea                   NaN         NaN          NaN
# LivAreaWt                 NaN         NaN          NaN
# AllSizesSum               NaN         NaN          NaN
# AllSizesSumLin            NaN         NaN          NaN
# AreasSum                  NaN         NaN          NaN
# X1stFlrSF                 NaN         NaN          NaN
# X1stLin                   NaN         NaN          NaN
# X2ndFlrSF                 NaN         NaN          NaN
# X2ndLin                   NaN         NaN          NaN
# TotalBath                 NaN         NaN          NaN
# BsmtFullBath              NaN         NaN          NaN
# BsmtHalfBath              NaN         NaN          NaN
# FullBath                  NaN         NaN          NaN
# HalfBath                  NaN         NaN          NaN
# Age                       NaN         NaN          NaN
# AgeLin                    NaN         NaN          NaN
# RemodAgeLin               NaN         NaN          NaN
# RemodAge                  NaN         NaN          NaN
# MasVnrArea                NaN         NaN          NaN
# MasVnrAreaLin             NaN         NaN          NaN
# DeckPorchLin              NaN         NaN          NaN
# WoodDeckSF                NaN         NaN          NaN
# OpenPorchSF               NaN         NaN          NaN
# EnclosedPorch             1.0         NaN          NaN
# X3SsnPorch                NaN         1.0          NaN
# ScreenPorch               NaN         NaN          1.0
#
# [33 rows x 33 columns]

# %% [markdown]
# We'll restrict our drop set to the highly correlated features to make this more readable,

# %%
drop_cands = [
    'LotArea', 'LogGrLivArea', 
    'GrLivArea', 'TotalHouseArea', 'LivArea', 'LivAreaWt', 'AllSizesSum', 'AreasSum',
    'X1stFlrSF','X1stLin', 'TotalBath', 'FullBath', 'MasVnrArea', 'MasVnrAreaLin'
]

# %%
corr_df = df[drop_cands].corr()

# %%
corr_df[corr_df > 0.75]
# Out:
#                                LotArea            LogGrLivArea  \
# LotArea         1.00000000000000000000                     NaN
# LogGrLivArea                       NaN  1.00000000000000000000
# GrLivArea                          NaN  0.97572734790673321115
# TotalHouseArea                     NaN  0.86058937220902298471
# LivArea                            NaN  0.76373332501539625827
# LivAreaWt                          NaN  0.91883982161090238527
# AllSizesSum     0.98606372397245245498                     NaN
# AreasSum                           NaN  0.83185505671546178252
# X1stFlrSF                          NaN                     NaN
# X1stLin                            NaN                     NaN
# TotalBath                          NaN                     NaN
# FullBath                           NaN                     NaN
# MasVnrArea                         NaN                     NaN
# MasVnrAreaLin                      NaN                     NaN
#
#                              GrLivArea          TotalHouseArea  \
# LotArea                            NaN                     NaN
# LogGrLivArea    0.97572734790673321115  0.86058937220902298471
# GrLivArea       1.00000000000000000000  0.83559555857857792383
# TotalHouseArea  0.83559555857857792383  1.00000000000000000000
# LivArea         0.76725195583060601390  0.80249169125840447148
# LivAreaWt       0.91377560660947887428  0.87595423074054235002
# AllSizesSum                        NaN                     NaN
# AreasSum        0.81989666984062914423  0.93233555658687905510
# X1stFlrSF                          NaN                     NaN
# X1stLin                            NaN                     NaN
# TotalBath                          NaN                     NaN
# FullBath                           NaN                     NaN
# MasVnrArea                         NaN                     NaN
# MasVnrAreaLin                      NaN                     NaN
#
#                                LivArea               LivAreaWt  \
# LotArea                            NaN                     NaN
# LogGrLivArea    0.76373332501539625827  0.91883982161090238527
# GrLivArea       0.76725195583060601390  0.91377560660947887428
# TotalHouseArea  0.80249169125840447148  0.87595423074054235002
# LivArea         1.00000000000000000000  0.94575036201415385584
# LivAreaWt       0.94575036201415385584  1.00000000000000000000
# AllSizesSum                        NaN                     NaN
# AreasSum        0.79502614267426652273  0.86132578116270241964
# X1stFlrSF                          NaN                     NaN
# X1stLin                            NaN                     NaN
# TotalBath                          NaN                     NaN
# FullBath                           NaN                     NaN
# MasVnrArea                         NaN                     NaN
# MasVnrAreaLin                      NaN                     NaN
#
#                            AllSizesSum                AreasSum  \
# LotArea         0.98606372397245245498                     NaN
# LogGrLivArea                       NaN  0.83185505671546178252
# GrLivArea                          NaN  0.81989666984062914423
# TotalHouseArea                     NaN  0.93233555658687905510
# LivArea                            NaN  0.79502614267426652273
# LivAreaWt                          NaN  0.86132578116270241964
# AllSizesSum     1.00000000000000000000                     NaN
# AreasSum                           NaN  1.00000000000000000000
# X1stFlrSF                          NaN                     NaN
# X1stLin                            NaN                     NaN
# TotalBath                          NaN                     NaN
# FullBath                           NaN                     NaN
# MasVnrArea                         NaN                     NaN
# MasVnrAreaLin                      NaN                     NaN
#
#                              X1stFlrSF                 X1stLin  \
# LotArea                            NaN                     NaN
# LogGrLivArea                       NaN                     NaN
# GrLivArea                          NaN                     NaN
# TotalHouseArea                     NaN                     NaN
# LivArea                            NaN                     NaN
# LivAreaWt                          NaN                     NaN
# AllSizesSum                        NaN                     NaN
# AreasSum                           NaN                     NaN
# X1stFlrSF       1.00000000000000000000  0.97902912343726755662
# X1stLin         0.97902912343726755662  1.00000000000000000000
# TotalBath                          NaN                     NaN
# FullBath                           NaN                     NaN
# MasVnrArea                         NaN                     NaN
# MasVnrAreaLin                      NaN                     NaN
#
#                              TotalBath                FullBath  \
# LotArea                            NaN                     NaN
# LogGrLivArea                       NaN                     NaN
# GrLivArea                          NaN                     NaN
# TotalHouseArea                     NaN                     NaN
# LivArea                            NaN                     NaN
# LivAreaWt                          NaN                     NaN
# AllSizesSum                        NaN                     NaN
# AreasSum                           NaN                     NaN
# X1stFlrSF                          NaN                     NaN
# X1stLin                            NaN                     NaN
# TotalBath       1.00000000000000000000  0.84275416767624933279
# FullBath        0.84275416767624933279  1.00000000000000000000
# MasVnrArea                         NaN                     NaN
# MasVnrAreaLin                      NaN                     NaN
#
#                             MasVnrArea           MasVnrAreaLin
# LotArea                            NaN                     NaN
# LogGrLivArea                       NaN                     NaN
# GrLivArea                          NaN                     NaN
# TotalHouseArea                     NaN                     NaN
# LivArea                            NaN                     NaN
# LivAreaWt                          NaN                     NaN
# AllSizesSum                        NaN                     NaN
# AreasSum                           NaN                     NaN
# X1stFlrSF                          NaN                     NaN
# X1stLin                            NaN                     NaN
# TotalBath                          NaN                     NaN
# FullBath                           NaN                     NaN
# MasVnrArea      1.00000000000000000000  0.91131509991048920138
# MasVnrAreaLin   0.91131509991048920138  1.00000000000000000000

# %% [markdown]
# Let's first compare the pairs.

# %%
drop_cands = ['LotArea', 'AllSizesSum']

# %%
col_drop_results_df = pd.DataFrame(dtype = 'float64')
count = 0
for L in range(0, len(drop_cands)+1):
        for subset in itertools.combinations(drop_cands, L):
                drop_cols = list(subset)
                col_drop_results_df.loc[count, 'Dropped'] = str(subset)
                x_train = train_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                x_validation = validation_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                lr.fit(x_train, y_train)
                y_pred = lr.predict(x_validation)
                error = rmse(y_validation, y_pred)
                col_drop_results_df.loc[count, 'RMSE'] = error
                col_drop_results_df.loc[count, 'Diff from Base'] = error - baseline                
                count += 1
output_df = col_drop_results_df.sort_values(['RMSE'])
# Out:
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 316 iterations, i.e. alpha=4.700e-06, with an active set of 238 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.966e-04, previous alpha=2.735e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=5.193e-04, previous alpha=2.280e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=2.184e-04, previous alpha=2.490e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.262e-04, previous alpha=2.377e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 236 iterations, i.e. alpha=1.691e-05, with an active set of 202 regressors, and the smallest cholesky pivot element being 2.788e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 237 iterations, i.e. alpha=1.686e-05, with an active set of 203 regressors, and the smallest cholesky pivot element being 2.788e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 239 iterations, alpha=1.646e-05, previous alpha=1.604e-05, with an active set of 204 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.003e-04, previous alpha=2.738e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=1.053e-03, previous alpha=4.008e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=6.580e-06, previous alpha=1.647e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=2.013e-04, previous alpha=2.888e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=3.549e-04, previous alpha=1.972e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 316 iterations, i.e. alpha=4.700e-06, with an active set of 238 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=5.228e-05, previous alpha=2.435e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=2.708e-04, previous alpha=2.490e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.908e-04, previous alpha=2.746e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.440e-04, previous alpha=2.377e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 230 iterations, i.e. alpha=1.854e-05, with an active set of 200 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 286 iterations, i.e. alpha=7.248e-06, with an active set of 234 regressors, and the smallest cholesky pivot element being 2.980e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=1.068e-03, previous alpha=4.008e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.319e-04, previous alpha=2.738e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=4.290e-04, previous alpha=2.846e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.772e-05, previous alpha=1.647e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=6.045e-04, previous alpha=1.972e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=2.830e-04, previous alpha=2.888e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 322 iterations, i.e. alpha=4.334e-06, with an active set of 244 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.909e-04, previous alpha=2.757e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=9.771e-05, previous alpha=2.489e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=1.422e-04, previous alpha=2.436e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=5.838e-05, previous alpha=2.456e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=2.037e-03, previous alpha=4.712e-06, with an active set of 242 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 228 iterations, i.e. alpha=1.880e-05, with an active set of 198 regressors, and the smallest cholesky pivot element being 2.980e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.319e-04, previous alpha=2.738e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 289 iterations, i.e. alpha=6.671e-06, with an active set of 237 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 290 iterations, alpha=6.671e-06, previous alpha=6.509e-06, with an active set of 237 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=5.367e-05, previous alpha=1.642e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 350 iterations, alpha=7.051e-04, previous alpha=2.677e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=4.338e-04, previous alpha=1.976e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=5.894e-04, previous alpha=2.535e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 316 iterations, i.e. alpha=4.477e-06, with an active set of 240 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.512e-05, previous alpha=2.740e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.347e-03, previous alpha=2.744e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=8.614e-05, previous alpha=2.478e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=3.807e-05, previous alpha=2.626e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 230 iterations, i.e. alpha=1.819e-05, with an active set of 202 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 280 iterations, i.e. alpha=8.346e-06, with an active set of 228 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 280 iterations, i.e. alpha=8.328e-06, with an active set of 228 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 320 iterations, i.e. alpha=4.173e-06, with an active set of 246 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 320 iterations, i.e. alpha=4.146e-06, with an active set of 246 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 321 iterations, alpha=4.168e-06, previous alpha=4.112e-06, with an active set of 246 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 351 iterations, alpha=1.626e-03, previous alpha=3.115e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=9.108e-05, previous alpha=1.593e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=7.056e-04, previous alpha=3.112e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=2.130e-05, previous alpha=1.830e-06, with an active set of 258 regressors.
#   ConvergenceWarning)

# %%
output_df
# Out:
#                       Dropped                    RMSE          Diff from Base
# 3  ('LotArea', 'AllSizesSum')  0.10470987736431239257 -0.00044819575820807811
# 1                ('LotArea',)  0.10489855064689157516 -0.00025952247562889552
# 0                          ()  0.10515807312252047068  0.00000000000000000000
# 2            ('AllSizesSum',)  0.10558597126726469717  0.00042789814474422649

# %% [markdown]
# We should keep these features.

# %%
drop_cands = ['X1stFlrSF','X1stLin']

# %%
col_drop_results_df = pd.DataFrame(dtype = 'float64')
count = 0
for L in range(0, len(drop_cands)+1):
        for subset in itertools.combinations(drop_cands, L):
                drop_cols = list(subset)
                col_drop_results_df.loc[count, 'Dropped'] = str(subset)
                x_train = train_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                x_validation = validation_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                lr.fit(x_train, y_train)
                y_pred = lr.predict(x_validation)
                error = rmse(y_validation, y_pred)
                col_drop_results_df.loc[count, 'RMSE'] = error
                col_drop_results_df.loc[count, 'Diff from Base'] = error - baseline                
                count += 1
output_df = col_drop_results_df.sort_values(['RMSE'])
# Out:
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.262e-04, previous alpha=2.377e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=5.193e-04, previous alpha=2.280e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=2.184e-04, previous alpha=2.490e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 316 iterations, i.e. alpha=4.700e-06, with an active set of 238 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.966e-04, previous alpha=2.735e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 236 iterations, i.e. alpha=1.691e-05, with an active set of 202 regressors, and the smallest cholesky pivot element being 2.788e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 237 iterations, i.e. alpha=1.686e-05, with an active set of 203 regressors, and the smallest cholesky pivot element being 2.788e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 239 iterations, alpha=1.646e-05, previous alpha=1.604e-05, with an active set of 204 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=1.053e-03, previous alpha=4.008e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.003e-04, previous alpha=2.738e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=6.580e-06, previous alpha=1.647e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=2.013e-04, previous alpha=2.888e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=3.549e-04, previous alpha=1.972e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=2.708e-04, previous alpha=2.490e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 316 iterations, i.e. alpha=4.700e-06, with an active set of 238 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=5.228e-05, previous alpha=2.435e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.908e-04, previous alpha=2.746e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.440e-04, previous alpha=2.377e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 230 iterations, i.e. alpha=1.854e-05, with an active set of 200 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.106e-04, previous alpha=2.714e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 286 iterations, i.e. alpha=7.248e-06, with an active set of 234 regressors, and the smallest cholesky pivot element being 2.980e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 329 iterations, i.e. alpha=3.729e-06, with an active set of 249 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=1.068e-03, previous alpha=4.008e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=4.290e-04, previous alpha=3.037e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=6.580e-06, previous alpha=1.657e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=2.830e-04, previous alpha=2.888e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=6.045e-04, previous alpha=1.972e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 330 iterations, i.e. alpha=3.715e-06, with an active set of 248 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.284e-04, previous alpha=2.762e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=3.965e-04, previous alpha=2.747e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 348 iterations, i.e. alpha=2.004e-06, with an active set of 262 regressors, and the smallest cholesky pivot element being 8.560e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=5.628e-05, previous alpha=2.004e-06, with an active set of 262 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.154e-04, previous alpha=2.308e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 203 iterations, i.e. alpha=2.542e-05, with an active set of 183 regressors, and the smallest cholesky pivot element being 2.356e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 298 iterations, alpha=6.373e-06, previous alpha=6.209e-06, with an active set of 237 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 350 iterations, alpha=1.084e-03, previous alpha=3.956e-06, with an active set of 249 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.106e-04, previous alpha=2.786e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.035e-03, previous alpha=1.656e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.588e-04, previous alpha=3.105e-06, with an active set of 249 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=2.302e-04, previous alpha=1.478e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=7.496e-05, previous alpha=2.017e-06, with an active set of 262 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 337 iterations, i.e. alpha=3.473e-06, with an active set of 251 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=3.556e-04, previous alpha=2.950e-06, with an active set of 246 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=6.432e-04, previous alpha=2.797e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=8.468e-04, previous alpha=2.188e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 212 iterations, i.e. alpha=2.034e-05, with an active set of 192 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 261 iterations, i.e. alpha=9.389e-06, with an active set of 223 regressors, and the smallest cholesky pivot element being 2.356e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=3.787e-04, previous alpha=3.027e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 262 iterations, i.e. alpha=9.059e-06, with an active set of 224 regressors, and the smallest cholesky pivot element being 2.356e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 271 iterations, alpha=8.752e-06, previous alpha=8.315e-06, with an active set of 232 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=3.382e-04, previous alpha=3.431e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=9.221e-05, previous alpha=1.584e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=5.887e-06, previous alpha=4.223e-06, with an active set of 244 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=2.036e-04, previous alpha=1.965e-06, with an active set of 257 regressors.
#   ConvergenceWarning)

# %%
output_df
# Out:
#                     Dropped                    RMSE          Diff from Base
# 1            ('X1stFlrSF',)  0.10463252277742572660 -0.00052555034509474408
# 2              ('X1stLin',)  0.10473275521008570954 -0.00042531791243476114
# 3  ('X1stFlrSF', 'X1stLin')  0.10481817416540835375 -0.00033989895711211693
# 0                        ()  0.10515807312252047068  0.00000000000000000000

# %%
drop_cands = ['TotalBath', 'FullBath']

# %%
col_drop_results_df = pd.DataFrame(dtype = 'float64')
count = 0
for L in range(0, len(drop_cands)+1):
        for subset in itertools.combinations(drop_cands, L):
                drop_cols = list(subset)
                col_drop_results_df.loc[count, 'Dropped'] = str(subset)
                x_train = train_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                x_validation = validation_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                lr.fit(x_train, y_train)
                y_pred = lr.predict(x_validation)
                error = rmse(y_validation, y_pred)
                col_drop_results_df.loc[count, 'RMSE'] = error
                col_drop_results_df.loc[count, 'Diff from Base'] = error - baseline                
                count += 1
output_df = col_drop_results_df.sort_values(['RMSE'])
# Out:
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 316 iterations, i.e. alpha=4.700e-06, with an active set of 238 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=5.193e-04, previous alpha=2.280e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=2.184e-04, previous alpha=2.490e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.966e-04, previous alpha=2.735e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.262e-04, previous alpha=2.377e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 236 iterations, i.e. alpha=1.691e-05, with an active set of 202 regressors, and the smallest cholesky pivot element being 2.788e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 237 iterations, i.e. alpha=1.686e-05, with an active set of 203 regressors, and the smallest cholesky pivot element being 2.788e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 239 iterations, alpha=1.646e-05, previous alpha=1.604e-05, with an active set of 204 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.003e-04, previous alpha=2.738e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=1.053e-03, previous alpha=4.008e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=6.580e-06, previous alpha=1.647e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=2.013e-04, previous alpha=2.888e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=3.549e-04, previous alpha=1.972e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 316 iterations, i.e. alpha=4.592e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 320 iterations, alpha=4.383e-06, previous alpha=4.340e-06, with an active set of 245 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.705e-05, previous alpha=2.288e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=4.652e-04, previous alpha=2.234e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=9.868e-05, previous alpha=2.201e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 227 iterations, i.e. alpha=1.792e-05, with an active set of 201 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 280 iterations, i.e. alpha=6.990e-06, with an active set of 234 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 283 iterations, i.e. alpha=6.572e-06, with an active set of 237 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 284 iterations, alpha=6.650e-06, previous alpha=6.489e-06, with an active set of 237 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=3.593e-04, previous alpha=2.746e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=3.383e-04, previous alpha=3.216e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=7.140e-05, previous alpha=1.537e-06, with an active set of 261 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=6.206e-05, previous alpha=2.674e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=7.158e-04, previous alpha=1.951e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.440e-04, previous alpha=2.377e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=2.708e-04, previous alpha=2.490e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 316 iterations, i.e. alpha=4.700e-06, with an active set of 238 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=5.228e-05, previous alpha=2.435e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.908e-04, previous alpha=2.746e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 230 iterations, i.e. alpha=1.854e-05, with an active set of 200 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.319e-04, previous alpha=2.738e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=1.068e-03, previous alpha=4.008e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 286 iterations, i.e. alpha=7.248e-06, with an active set of 234 regressors, and the smallest cholesky pivot element being 2.980e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 329 iterations, i.e. alpha=3.729e-06, with an active set of 249 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.772e-05, previous alpha=1.647e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=4.290e-04, previous alpha=3.037e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=2.830e-04, previous alpha=2.888e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=6.045e-04, previous alpha=1.972e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=9.991e-06, previous alpha=2.416e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=4.922e-04, previous alpha=2.705e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=3.100e-04, previous alpha=2.971e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=3.111e-05, previous alpha=2.143e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 242 iterations, i.e. alpha=1.598e-05, with an active set of 208 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=1.402e-04, previous alpha=3.011e-06, with an active set of 250 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 281 iterations, i.e. alpha=7.494e-06, with an active set of 233 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 282 iterations, alpha=7.494e-06, previous alpha=7.312e-06, with an active set of 233 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=3.944e-05, previous alpha=2.783e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.549e-04, previous alpha=1.319e-06, with an active set of 261 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.353e-04, previous alpha=3.107e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.649e-04, previous alpha=1.786e-06, with an active set of 258 regressors.
#   ConvergenceWarning)

# %%
output_df
# Out:
#                      Dropped                    RMSE          Diff from Base
# 1             ('TotalBath',)  0.10439929425887752024 -0.00075877886364295044
# 3  ('TotalBath', 'FullBath')  0.10444268741494927566 -0.00071538570757119502
# 2              ('FullBath',)  0.10489855064689154740 -0.00025952247562892328
# 0                         ()  0.10515807312252047068  0.00000000000000000000

# %% [markdown]
# The gain by dropping both of these isn't big enough to consider dropping a predictor that we'd consider strong by hedonic reasoning.

# %%
drop_cands = ['MasVnrArea', 'MasVnrAreaLin']

# %%
col_drop_results_df = pd.DataFrame(dtype = 'float64')
count = 0
for L in range(0, len(drop_cands)+1):
        for subset in itertools.combinations(drop_cands, L):
                drop_cols = list(subset)
                col_drop_results_df.loc[count, 'Dropped'] = str(subset)
                x_train = train_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                x_validation = validation_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                lr.fit(x_train, y_train)
                y_pred = lr.predict(x_validation)
                error = rmse(y_validation, y_pred)
                col_drop_results_df.loc[count, 'RMSE'] = error
                col_drop_results_df.loc[count, 'Diff from Base'] = error - baseline                
                count += 1
output_df = col_drop_results_df.sort_values(['RMSE'])
# Out:
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=5.193e-04, previous alpha=2.280e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=2.184e-04, previous alpha=2.490e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 316 iterations, i.e. alpha=4.700e-06, with an active set of 238 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.966e-04, previous alpha=2.735e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.262e-04, previous alpha=2.377e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 236 iterations, i.e. alpha=1.691e-05, with an active set of 202 regressors, and the smallest cholesky pivot element being 2.788e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 237 iterations, i.e. alpha=1.686e-05, with an active set of 203 regressors, and the smallest cholesky pivot element being 2.788e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 239 iterations, alpha=1.646e-05, previous alpha=1.604e-05, with an active set of 204 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.003e-04, previous alpha=2.738e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=1.053e-03, previous alpha=4.008e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=6.580e-06, previous alpha=1.647e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=3.549e-04, previous alpha=1.972e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=2.013e-04, previous alpha=2.888e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=7.565e-05, previous alpha=2.407e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 307 iterations, i.e. alpha=5.134e-06, with an active set of 233 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=5.228e-05, previous alpha=2.552e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=6.061e-04, previous alpha=2.586e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=3.778e-04, previous alpha=2.740e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.220e-03, previous alpha=2.256e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=3.243e-04, previous alpha=3.903e-06, with an active set of 247 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 259 iterations, i.e. alpha=1.172e-05, with an active set of 213 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 260 iterations, i.e. alpha=1.172e-05, with an active set of 214 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 308 iterations, i.e. alpha=4.763e-06, with an active set of 250 regressors, and the smallest cholesky pivot element being 2.788e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 319 iterations, i.e. alpha=4.138e-06, with an active set of 247 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 319 iterations, i.e. alpha=4.044e-06, with an active set of 247 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 320 iterations, alpha=4.138e-06, previous alpha=4.037e-06, with an active set of 247 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.035e-03, previous alpha=1.499e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.013e-04, previous alpha=2.887e-06, with an active set of 249 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=4.494e-04, previous alpha=1.675e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 316 iterations, i.e. alpha=4.756e-06, with an active set of 236 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.874e-04, previous alpha=2.736e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=2.708e-04, previous alpha=2.474e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=1.080e-03, previous alpha=2.219e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.440e-04, previous alpha=2.377e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 230 iterations, i.e. alpha=1.854e-05, with an active set of 200 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 247 iterations, i.e. alpha=1.438e-05, with an active set of 211 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 263 iterations, i.e. alpha=1.117e-05, with an active set of 217 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 286 iterations, i.e. alpha=7.582e-06, with an active set of 234 regressors, and the smallest cholesky pivot element being 2.980e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.106e-04, previous alpha=2.704e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=1.068e-03, previous alpha=4.008e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 325 iterations, i.e. alpha=4.004e-06, with an active set of 249 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 325 iterations, i.e. alpha=3.963e-06, with an active set of 249 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 325 iterations, i.e. alpha=3.853e-06, with an active set of 249 regressors, and the smallest cholesky pivot element being 7.451e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 326 iterations, alpha=3.894e-06, previous alpha=3.841e-06, with an active set of 249 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=5.660e-05, previous alpha=1.516e-06, with an active set of 261 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.013e-04, previous alpha=2.902e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=7.431e-04, previous alpha=1.784e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=7.565e-05, previous alpha=2.408e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=1.223e-03, previous alpha=2.219e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 307 iterations, i.e. alpha=5.134e-06, with an active set of 233 regressors, and the smallest cholesky pivot element being 3.650e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.237e-04, previous alpha=2.271e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=6.061e-04, previous alpha=2.580e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 259 iterations, i.e. alpha=1.172e-05, with an active set of 213 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 260 iterations, i.e. alpha=1.172e-05, with an active set of 214 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.003e-04, previous alpha=2.703e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=3.269e-04, previous alpha=3.903e-06, with an active set of 247 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 308 iterations, i.e. alpha=4.763e-06, with an active set of 250 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 319 iterations, i.e. alpha=4.138e-06, with an active set of 247 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 319 iterations, i.e. alpha=4.044e-06, with an active set of 247 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.035e-03, previous alpha=1.498e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 320 iterations, alpha=4.138e-06, previous alpha=4.037e-06, with an active set of 247 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=1.097e-03, previous alpha=1.548e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=3.809e-04, previous alpha=2.911e-06, with an active set of 250 regressors.
#   ConvergenceWarning)

# %%
output_df
# Out:
#                            Dropped                    RMSE  \
# 2               ('MasVnrAreaLin',)  0.10463252277742572660
# 3  ('MasVnrArea', 'MasVnrAreaLin')  0.10468839374557338540
# 1                  ('MasVnrArea',)  0.10468851377983115492
# 0                               ()  0.10515807312252047068
#
#            Diff from Base
# 2 -0.00052555034509474408
# 3 -0.00046967937694708528
# 1 -0.00046955934268931576
# 0  0.00000000000000000000

# %%
drop_cands = ['LogGrLivArea', 'GrLivArea', 'TotalHouseArea', 'LivArea', 'LivAreaWt', 'AreasSum']

# %%
col_drop_results_df = pd.DataFrame(dtype = 'float64')
count = 0
for L in range(0, len(drop_cands)+1):
        for subset in itertools.combinations(drop_cands, L):
                drop_cols = list(subset)
                col_drop_results_df.loc[count, 'Dropped'] = str(subset)
                x_train = train_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                x_validation = validation_df.drop(['HouseId', 'SalePrice', 'GarageAge', 'GarageAgeLin'] + drop_cols,axis=1).values
                lr.fit(x_train, y_train)
                y_pred = lr.predict(x_validation)
                error = rmse(y_validation, y_pred)
                col_drop_results_df.loc[count, 'RMSE'] = error
                col_drop_results_df.loc[count, 'Diff from Base'] = error - baseline                
                count += 1
output_df = col_drop_results_df.sort_values(['RMSE'])
# Out:
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=2.184e-04, previous alpha=2.490e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 316 iterations, i.e. alpha=4.700e-06, with an active set of 238 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.966e-04, previous alpha=2.735e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=5.193e-04, previous alpha=2.280e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.262e-04, previous alpha=2.377e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 236 iterations, i.e. alpha=1.691e-05, with an active set of 202 regressors, and the smallest cholesky pivot element being 2.788e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 237 iterations, i.e. alpha=1.686e-05, with an active set of 203 regressors, and the smallest cholesky pivot element being 2.788e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 239 iterations, alpha=1.646e-05, previous alpha=1.604e-05, with an active set of 204 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.003e-04, previous alpha=2.738e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=1.053e-03, previous alpha=4.008e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=6.580e-06, previous alpha=1.647e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=2.013e-04, previous alpha=2.888e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=3.549e-04, previous alpha=1.972e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=5.291e-05, previous alpha=2.335e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 350 iterations, alpha=1.118e-03, previous alpha=2.372e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 303 iterations, i.e. alpha=5.484e-06, with an active set of 239 regressors, and the smallest cholesky pivot element being 3.942e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=7.224e-05, previous alpha=2.257e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.347e-03, previous alpha=2.377e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=3.117e-05, previous alpha=4.198e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.930e-04, previous alpha=2.737e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 228 iterations, i.e. alpha=1.841e-05, with an active set of 200 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 240 iterations, i.e. alpha=1.492e-05, with an active set of 210 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 242 iterations, alpha=1.487e-05, previous alpha=1.485e-05, with an active set of 211 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=9.116e-05, previous alpha=1.454e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.292e-04, previous alpha=3.128e-06, with an active set of 249 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.782e-04, previous alpha=1.641e-06, with an active set of 261 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 315 iterations, i.e. alpha=4.574e-06, with an active set of 243 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.905e-04, previous alpha=2.903e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=2.435e-04, previous alpha=2.507e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.808e-04, previous alpha=2.587e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 351 iterations, alpha=1.290e-03, previous alpha=2.286e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 334 iterations, i.e. alpha=2.589e-06, with an active set of 250 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.642e-04, previous alpha=2.175e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=2.004e-04, previous alpha=2.778e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=3.097e-04, previous alpha=3.903e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.836e-05, previous alpha=1.811e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=3.487e-05, previous alpha=1.613e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.700e-04, previous alpha=2.978e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=1.651e-04, previous alpha=2.425e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 352 iterations, alpha=1.535e-04, previous alpha=2.061e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 312 iterations, i.e. alpha=4.700e-06, with an active set of 238 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 327 iterations, i.e. alpha=3.399e-06, with an active set of 247 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 331 iterations, alpha=3.064e-06, previous alpha=3.004e-06, with an active set of 250 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.806e-04, previous alpha=2.287e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 236 iterations, i.e. alpha=1.590e-05, with an active set of 204 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 251 iterations, i.e. alpha=1.311e-05, with an active set of 215 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 251 iterations, i.e. alpha=1.293e-05, with an active set of 215 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 266 iterations, alpha=1.076e-05, previous alpha=1.059e-05, with an active set of 221 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=1.051e-03, previous alpha=3.977e-06, with an active set of 246 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 350 iterations, alpha=9.205e-05, previous alpha=2.160e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.035e-03, previous alpha=1.523e-06, with an active set of 262 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.700e-05, previous alpha=1.706e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=1.211e-03, previous alpha=3.065e-06, with an active set of 247 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=9.724e-05, previous alpha=3.283e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.443e-04, previous alpha=2.501e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.714e-04, previous alpha=2.206e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.478e-04, previous alpha=2.385e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 221 iterations, i.e. alpha=1.885e-05, with an active set of 197 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 228 iterations, i.e. alpha=1.715e-05, with an active set of 202 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 238 iterations, alpha=1.473e-05, previous alpha=1.451e-05, with an active set of 211 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.964e-04, previous alpha=2.649e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=9.153e-06, previous alpha=1.470e-06, with an active set of 262 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=9.839e-04, previous alpha=4.008e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=5.733e-04, previous alpha=2.747e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=7.397e-04, previous alpha=1.793e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.366e-04, previous alpha=2.976e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=3.374e-04, previous alpha=2.280e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=7.021e-05, previous alpha=2.407e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 312 iterations, i.e. alpha=4.695e-06, with an active set of 238 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 315 iterations, alpha=4.539e-06, previous alpha=4.475e-06, with an active set of 240 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 227 iterations, i.e. alpha=1.879e-05, with an active set of 199 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 236 iterations, i.e. alpha=1.586e-05, with an active set of 204 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 261 iterations, i.e. alpha=1.094e-05, with an active set of 219 regressors, and the smallest cholesky pivot element being 2.980e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.241e-04, previous alpha=2.738e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 325 iterations, alpha=3.636e-06, previous alpha=3.636e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=5.691e-04, previous alpha=3.329e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=5.604e-05, previous alpha=1.647e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=5.844e-04, previous alpha=2.678e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=1.306e-03, previous alpha=1.779e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 313 iterations, i.e. alpha=4.889e-06, with an active set of 243 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 314 iterations, i.e. alpha=4.674e-06, with an active set of 244 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=1.013e-04, previous alpha=2.471e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 314 iterations, i.e. alpha=4.459e-06, with an active set of 244 regressors, and the smallest cholesky pivot element being 3.942e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 315 iterations, alpha=4.853e-06, previous alpha=4.415e-06, with an active set of 244 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.103e-05, previous alpha=2.365e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=6.260e-05, previous alpha=2.503e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 227 iterations, i.e. alpha=1.860e-05, with an active set of 199 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 266 iterations, i.e. alpha=1.001e-05, with an active set of 220 regressors, and the smallest cholesky pivot element being 2.980e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 266 iterations, i.e. alpha=9.941e-06, with an active set of 220 regressors, and the smallest cholesky pivot element being 2.980e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 301 iterations, i.e. alpha=5.004e-06, with an active set of 245 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 331 iterations, alpha=3.374e-06, previous alpha=3.283e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=4.017e-05, previous alpha=3.916e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 350 iterations, alpha=4.940e-04, previous alpha=2.735e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=7.902e-05, previous alpha=1.798e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=1.060e-04, previous alpha=2.727e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=5.296e-05, previous alpha=1.594e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=2.290e-05, previous alpha=3.366e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 322 iterations, i.e. alpha=3.665e-06, with an active set of 246 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=6.941e-04, previous alpha=2.232e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=7.235e-05, previous alpha=3.393e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=1.377e-04, previous alpha=2.460e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 235 iterations, i.e. alpha=1.515e-05, with an active set of 205 regressors, and the smallest cholesky pivot element being 3.942e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 254 iterations, i.e. alpha=1.080e-05, with an active set of 216 regressors, and the smallest cholesky pivot element being 2.356e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 255 iterations, alpha=1.056e-05, previous alpha=1.041e-05, with an active set of 216 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 347 iterations, alpha=2.850e-04, previous alpha=2.604e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.715e-04, previous alpha=3.785e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=7.577e-06, previous alpha=1.678e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=5.226e-04, previous alpha=3.019e-06, with an active set of 249 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=2.782e-05, previous alpha=1.683e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.439e-04, previous alpha=2.810e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 301 iterations, i.e. alpha=4.992e-06, with an active set of 243 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 302 iterations, alpha=4.930e-06, previous alpha=4.924e-06, with an active set of 243 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=8.988e-05, previous alpha=2.518e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 353 iterations, alpha=3.936e-04, previous alpha=1.934e-06, with an active set of 260 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 350 iterations, alpha=1.089e-03, previous alpha=2.112e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 291 iterations, i.e. alpha=7.356e-06, with an active set of 233 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=3.714e-04, previous alpha=3.671e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=5.380e-04, previous alpha=3.456e-06, with an active set of 249 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=6.439e-06, previous alpha=1.508e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=8.431e-05, previous alpha=2.993e-06, with an active set of 245 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=8.668e-05, previous alpha=1.495e-06, with an active set of 261 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 301 iterations, i.e. alpha=5.484e-06, with an active set of 239 regressors, and the smallest cholesky pivot element being 3.942e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=7.971e-05, previous alpha=2.751e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=2.994e-05, previous alpha=2.409e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 332 iterations, i.e. alpha=2.756e-06, with an active set of 250 regressors, and the smallest cholesky pivot element being 3.650e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=7.301e-04, previous alpha=2.195e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.231e-03, previous alpha=2.377e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 221 iterations, i.e. alpha=1.872e-05, with an active set of 197 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 226 iterations, i.e. alpha=1.742e-05, with an active set of 200 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 239 iterations, alpha=1.428e-05, previous alpha=1.409e-05, with an active set of 212 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=4.122e-04, previous alpha=3.919e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=1.116e-04, previous alpha=2.661e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=9.197e-06, previous alpha=1.440e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.419e-04, previous alpha=3.025e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=2.777e-05, previous alpha=1.725e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 306 iterations, i.e. alpha=5.156e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 4.215e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 308 iterations, i.e. alpha=5.074e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 308 iterations, i.e. alpha=4.894e-06, with an active set of 242 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 309 iterations, i.e. alpha=4.780e-06, with an active set of 243 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 311 iterations, alpha=4.898e-06, previous alpha=4.672e-06, with an active set of 244 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=3.574e-05, previous alpha=2.582e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 349 iterations, alpha=1.533e-04, previous alpha=2.257e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=2.332e-04, previous alpha=2.496e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 228 iterations, i.e. alpha=1.812e-05, with an active set of 200 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 241 iterations, i.e. alpha=1.518e-05, with an active set of 207 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 242 iterations, i.e. alpha=1.471e-05, with an active set of 208 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# ...
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=2.358e-04, previous alpha=2.874e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.522e-04, previous alpha=3.767e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=2.547e-04, previous alpha=2.171e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=1.291e-04, previous alpha=2.461e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=2.913e-04, previous alpha=2.143e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=2.169e-04, previous alpha=3.389e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 288 iterations, i.e. alpha=7.569e-06, with an active set of 228 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 298 iterations, i.e. alpha=5.982e-06, with an active set of 234 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 298 iterations, i.e. alpha=5.914e-06, with an active set of 234 regressors, and the smallest cholesky pivot element being 7.885e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 302 iterations, alpha=5.581e-06, previous alpha=5.258e-06, with an active set of 237 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 340 iterations, alpha=8.916e-05, previous alpha=2.323e-06, with an active set of 259 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 340 iterations, alpha=1.124e-04, previous alpha=2.326e-06, with an active set of 249 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 344 iterations, alpha=2.498e-04, previous alpha=2.426e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 223 iterations, i.e. alpha=1.858e-05, with an active set of 193 regressors, and the smallest cholesky pivot element being 2.356e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 225 iterations, i.e. alpha=1.852e-05, with an active set of 193 regressors, and the smallest cholesky pivot element being 2.356e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 225 iterations, i.e. alpha=1.849e-05, with an active set of 193 regressors, and the smallest cholesky pivot element being 2.356e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 227 iterations, alpha=1.740e-05, previous alpha=1.687e-05, with an active set of 194 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=1.859e-04, previous alpha=3.785e-06, with an active set of 245 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 340 iterations, alpha=3.006e-04, previous alpha=3.701e-06, with an active set of 241 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=1.471e-04, previous alpha=1.780e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 340 iterations, alpha=2.418e-04, previous alpha=2.121e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 346 iterations, alpha=1.725e-04, previous alpha=2.306e-06, with an active set of 255 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 307 iterations, i.e. alpha=4.544e-06, with an active set of 243 regressors, and the smallest cholesky pivot element being 3.942e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 345 iterations, alpha=8.299e-04, previous alpha=2.151e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 308 iterations, i.e. alpha=4.532e-06, with an active set of 244 regressors, and the smallest cholesky pivot element being 3.942e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 348 iterations, alpha=1.597e-04, previous alpha=2.718e-06, with an active set of 257 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 308 iterations, i.e. alpha=4.480e-06, with an active set of 244 regressors, and the smallest cholesky pivot element being 5.867e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 310 iterations, alpha=4.294e-06, previous alpha=4.130e-06, with an active set of 245 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 343 iterations, alpha=1.257e-04, previous alpha=3.047e-06, with an active set of 250 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 226 iterations, i.e. alpha=1.782e-05, with an active set of 198 regressors, and the smallest cholesky pivot element being 2.788e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 246 iterations, i.e. alpha=1.278e-05, with an active set of 216 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 247 iterations, alpha=1.271e-05, previous alpha=1.231e-05, with an active set of 216 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=1.846e-04, previous alpha=3.380e-06, with an active set of 253 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=1.026e-05, previous alpha=2.033e-06, with an active set of 256 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=3.036e-04, previous alpha=2.076e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=3.181e-04, previous alpha=3.005e-06, with an active set of 254 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=1.480e-04, previous alpha=3.461e-06, with an active set of 246 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 339 iterations, alpha=7.513e-05, previous alpha=2.282e-06, with an active set of 258 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 338 iterations, alpha=3.150e-04, previous alpha=2.545e-06, with an active set of 251 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 339 iterations, alpha=6.038e-04, previous alpha=2.201e-06, with an active set of 252 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 179 iterations, i.e. alpha=4.264e-05, with an active set of 159 regressors, and the smallest cholesky pivot element being 3.332e-08
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 274 iterations, i.e. alpha=7.580e-06, with an active set of 222 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 339 iterations, alpha=1.017e-04, previous alpha=3.112e-06, with an active set of 250 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 282 iterations, alpha=6.347e-06, previous alpha=6.281e-06, with an active set of 229 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 339 iterations, alpha=3.612e-06, previous alpha=3.570e-06, with an active set of 248 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=2.514e-04, previous alpha=2.324e-06, with an active set of 246 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 341 iterations, alpha=6.971e-06, previous alpha=3.716e-06, with an active set of 244 regressors.
#   ConvergenceWarning)
# /usr/lib64/python2.7/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 340 iterations, alpha=1.292e-04, previous alpha=2.311e-06, with an active set of 251 regressors.
#   ConvergenceWarning)

# %%
output_df
# Out:
#                                                                                 Dropped  \
# 59             ('LogGrLivArea', 'GrLivArea', 'TotalHouseArea', 'LivAreaWt', 'AreasSum')
# 58               ('LogGrLivArea', 'GrLivArea', 'TotalHouseArea', 'LivArea', 'AreasSum')
# 28                                       ('LogGrLivArea', 'TotalHouseArea', 'AreasSum')
# 18                                                       ('TotalHouseArea', 'AreasSum')
# 63  ('LogGrLivArea', 'GrLivArea', 'TotalHouseArea', 'LivArea', 'LivAreaWt', 'AreasSum')
# 49                            ('LogGrLivArea', 'TotalHouseArea', 'LivArea', 'AreasSum')
# 39                                            ('TotalHouseArea', 'LivArea', 'AreasSum')
# 40                                          ('TotalHouseArea', 'LivAreaWt', 'AreasSum')
# 47                               ('LogGrLivArea', 'GrLivArea', 'LivAreaWt', 'AreasSum')
# 34                                          ('GrLivArea', 'TotalHouseArea', 'AreasSum')
# 50                          ('LogGrLivArea', 'TotalHouseArea', 'LivAreaWt', 'AreasSum')
# 53                               ('GrLivArea', 'TotalHouseArea', 'LivArea', 'AreasSum')
# 21                                                            ('LivAreaWt', 'AreasSum')
# 24                                           ('LogGrLivArea', 'GrLivArea', 'LivAreaWt')
# 46                                 ('LogGrLivArea', 'GrLivArea', 'LivArea', 'AreasSum')
# 61               ('LogGrLivArea', 'TotalHouseArea', 'LivArea', 'LivAreaWt', 'AreasSum')
# 6                                                                         ('AreasSum',)
# 11                                                         ('LogGrLivArea', 'AreasSum')
# 20                                                              ('LivArea', 'AreasSum')
# 30                                              ('LogGrLivArea', 'LivArea', 'AreasSum')
# 36                                                 ('GrLivArea', 'LivArea', 'AreasSum')
# 51                                 ('LogGrLivArea', 'LivArea', 'LivAreaWt', 'AreasSum')
# 56                               ('TotalHouseArea', 'LivArea', 'LivAreaWt', 'AreasSum')
# 15                                                            ('GrLivArea', 'AreasSum')
# 60                    ('LogGrLivArea', 'GrLivArea', 'LivArea', 'LivAreaWt', 'AreasSum')
# 31                                            ('LogGrLivArea', 'LivAreaWt', 'AreasSum')
# 54                             ('GrLivArea', 'TotalHouseArea', 'LivAreaWt', 'AreasSum')
# 4                                                                          ('LivArea',)
# 17                                                      ('TotalHouseArea', 'LivAreaWt')
# 7                                                         ('LogGrLivArea', 'GrLivArea')
# ..                                                                                  ...
# 26                                        ('LogGrLivArea', 'TotalHouseArea', 'LivArea')
# 29                                             ('LogGrLivArea', 'LivArea', 'LivAreaWt')
# 57              ('LogGrLivArea', 'GrLivArea', 'TotalHouseArea', 'LivArea', 'LivAreaWt')
# 22                                      ('LogGrLivArea', 'GrLivArea', 'TotalHouseArea')
# 23                                             ('LogGrLivArea', 'GrLivArea', 'LivArea')
# 19                                                             ('LivArea', 'LivAreaWt')
# 2                                                                        ('GrLivArea',)
# 32                                           ('GrLivArea', 'TotalHouseArea', 'LivArea')
# 42                           ('LogGrLivArea', 'GrLivArea', 'TotalHouseArea', 'LivArea')
# 8                                                    ('LogGrLivArea', 'TotalHouseArea')
# 1                                                                     ('LogGrLivArea',)
# 9                                                           ('LogGrLivArea', 'LivArea')
# 27                                      ('LogGrLivArea', 'TotalHouseArea', 'LivAreaWt')
# 25                                            ('LogGrLivArea', 'GrLivArea', 'AreasSum')
# 12                                                      ('GrLivArea', 'TotalHouseArea')
# 38                                           ('TotalHouseArea', 'LivArea', 'LivAreaWt')
# 5                                                                        ('LivAreaWt',)
# 37                                               ('GrLivArea', 'LivAreaWt', 'AreasSum')
# 0                                                                                    ()
# 48                           ('LogGrLivArea', 'TotalHouseArea', 'LivArea', 'LivAreaWt')
# 33                                         ('GrLivArea', 'TotalHouseArea', 'LivAreaWt')
# 13                                                             ('GrLivArea', 'LivArea')
# 45                                ('LogGrLivArea', 'GrLivArea', 'LivArea', 'LivAreaWt')
# 14                                                           ('GrLivArea', 'LivAreaWt')
# 55                                    ('GrLivArea', 'LivArea', 'LivAreaWt', 'AreasSum')
# 35                                                ('GrLivArea', 'LivArea', 'LivAreaWt')
# 52                              ('GrLivArea', 'TotalHouseArea', 'LivArea', 'LivAreaWt')
# 62                  ('GrLivArea', 'TotalHouseArea', 'LivArea', 'LivAreaWt', 'AreasSum')
# 3                                                                   ('TotalHouseArea',)
# 10                                                        ('LogGrLivArea', 'LivAreaWt')
#
#                       RMSE          Diff from Base
# 59  0.10357174216942341416 -0.00158633095309705652
# 58  0.10391536481195215447 -0.00124270831056831621
# 28  0.10392310840042916220 -0.00123496472209130848
# 18  0.10393780236413910356 -0.00122027075838136712
# 63  0.10394131820957328016 -0.00121675491294719051
# 49  0.10397951960735733745 -0.00117855351516313323
# 39  0.10399046011626059127 -0.00116761300625987940
# 40  0.10417000486085599420 -0.00098806826166447648
# 47  0.10419650500599279830 -0.00096156811652767238
# 34  0.10423569331575052721 -0.00092237980676994347
# 50  0.10423886173556151657 -0.00091921138695895410
# 53  0.10424403024349621072 -0.00091404287902425996
# 21  0.10436940862604578151 -0.00078866449647468917
# 24  0.10441758877241671954 -0.00074048435010375113
# 46  0.10443914072119431236 -0.00071893240132615832
# 61  0.10445302980644410873 -0.00070504331607636195
# 6   0.10448274793895571955 -0.00067532518356475113
# 11  0.10448274793895596935 -0.00067532518356450133
# 20  0.10452729293985127401 -0.00063078018266919667
# 30  0.10453007278378549649 -0.00062800033873497418
# 36  0.10454708521440367330 -0.00061098790811679737
# 51  0.10458659247732551845 -0.00057148064519495223
# 56  0.10462447048805893768 -0.00053360263446153300
# 15  0.10465011875750289405 -0.00050795436501757663
# 60  0.10466194888446087030 -0.00049612423805960038
# 31  0.10469643580612794653 -0.00046163731639252414
# 54  0.10470730941021473559 -0.00045076371230573509
# 4   0.10471479683358576873 -0.00044327628893470195
# 17  0.10472131204273853189 -0.00043676107978193879
# 7   0.10473926437840894166 -0.00041880874411152902
# ..                     ...                     ...
# 26  0.10483256482699999934 -0.00032550829552047134
# 29  0.10484066603237368609 -0.00031740709014678459
# 57  0.10485822296715943680 -0.00029985015536103388
# 22  0.10486645690092610828 -0.00029161622159436240
# 23  0.10487024253905757876 -0.00028783058346289192
# 19  0.10488765911745188963 -0.00027041400506858104
# 2   0.10489257105933522118 -0.00026550206318524949
# 32  0.10491493911217487922 -0.00024313401034559146
# 42  0.10491493911217496249 -0.00024313401034550819
# 8   0.10491646862043876864 -0.00024160450208170203
# 1   0.10491808994056013582 -0.00023998318196033486
# 9   0.10492878437212734000 -0.00022928875039313068
# 27  0.10501736679877508862 -0.00014070632374538206
# 25  0.10502718839902737413 -0.00013088472349309654
# 12  0.10507462716214086007 -0.00008344596037961061
# 38  0.10508846359618664867 -0.00006960952633382200
# 5   0.10510130131835986045 -0.00005677180416061023
# 37  0.10513743848115424118 -0.00002063464136622950
# 0   0.10515807312252047068  0.00000000000000000000
# 48  0.10516789260590518607  0.00000981948338471539
# 33  0.10520940059589040105  0.00005132747336993038
# 13  0.10527498364851947676  0.00011691052599900609
# 45  0.10540366253586370970  0.00024558941334323903
# 14  0.10552543052192329964  0.00036735739940282897
# 55  0.10560749544360058250  0.00044942232108011182
# 35  0.10579848338721180301  0.00064041026469133233
# 52  0.10582209429741455675  0.00066402117489408607
# 62  0.10587938154262999113  0.00072130842010952045
# 3   0.10629903863942923026  0.00114096551690875958
# 10  0.10631499243426953405  0.00115691931174906337
#
# [64 rows x 3 columns]
